# %% [markdown]
# MAKE SURE YOU HAVE NECESSARY REQUIREMENTS AND CORPUSES AS TEI FILES

# %%
import csv
import sys
import copy
from pathlib import Path
from itertools import combinations
from collections import defaultdict

import pandas as pd
import networkx as nx
from bs4 import BeautifulSoup

SHAKESPEAR_GENRES = {"a-midsummer-nights-dream": "Comedy",
                     "alls-well-that-ends-well": "Comedy",
                     "antony-and-cleopatra": "Tragedy",
                     "as-you-like-it": "Comedy",
                     "coriolanus": "Tragedy",
                     "cymbeline": "Tragedy",
                     "hamlet": "Tragedy",
                     "henry-iv-part-i": "Tragedy",
                     "henry-iv-part-1": "Tragedy",
                     "henry-iv-part-ii": "Tragedy",
                     "henry-iv-part-2": "Tragedy",
                     "henry-v": "Tragedy",
                     "henry-vi-part-1": "Tragedy",
                     "henry-vi-part-2": "Tragedy",
                     "henry-vi-part-3": "Tragedy",
                     "henry-viii": "Tragedy",
                     "julius-caesar": "Tragedy",
                     "king-john": "Tragedy",
                     "king-lear": "Tragedy",
                     "loves-labors-lost": "Comedy",
                     "macbeth": "Tragedy",
                     "measure-for-measure": "Comedy",
                     "much-ado-about-nothing": "Comedy",
                     "othello": "Tragedy",
                     "pericles": "Tragedy",
                     "richard-ii": "Tragedy",
                     "richard-iii": "Tragedy",
                     "romeo-and-juliet": "Tragedy",
                     "the-comedy-of-errors": "Comedy",
                     "the-merchant-of-venice": "Comedy",
                     "the-merry-wives-of-windsor": "Comedy",
                     "the-taming-of-the-shrew": "Comedy",
                     "the-tempest": "Comedy",
                     "the-winters-tale": "Comedy",
                     "timon-of-athens": "Tragedy",
                     "titus-andronicus": "Tragedy",
                     "troilus-and-cressida": "Tragedy",
                     "twelfth-night": "Comedy",
                     "two-gentlemen-of-verona": "Comedy"
                     }

# %% [markdown]
# **FILES**

# %%
shakespear_tei_files = '/home/misinagy/Projects/shakedracor/tei'
gerdracor_tei_files = 'gerdracor/tei'
original_gerdracor_metadata_file = 'gerdracor-metadata.csv'

# %% [markdown]
# **HELPERS**

# %%
def get_largest_G(input_G, name=None):
    """
    Function to extract largest connected section of nx Graph object.
    """
    if len(input_G.nodes) == 0:
        raise ValueError(f'ZERO NODE GRAPH PASSED TO get_largest_G - {input_G}: {name}')
    if nx.is_connected(input_G) is False:
        # larges connected section
        nodes_in_largest = max(nx.connected_components(input_G), key=len)
        nodes_to_remove = set(input_G.nodes) - nodes_in_largest
        G_copy = input_G.copy()
        G_copy.remove_nodes_from(nodes_to_remove)
        return G_copy
    else:
        return input_G

# %% [markdown]
# <h3>SHAKESPEAR ANALYSIS</h3>

# %%
# open xml files and parse soups
shake_soups = {}
for xml_path in Path(shakespear_tei_files).glob('*.xml'):
    print(xml_path)
    with open(xml_path, 'r') as fh:
        shake_soups[xml_path.stem] = BeautifulSoup(fh.read(), 'lxml-xml')
# Out:
# /home/misinagy/Projects/shakedracor/tei/a-midsummer-nights-dream.xml
# /home/misinagy/Projects/shakedracor/tei/the-tempest.xml
# /home/misinagy/Projects/shakedracor/tei/two-gentlemen-of-verona.xml
# /home/misinagy/Projects/shakedracor/tei/the-taming-of-the-shrew.xml
# /home/misinagy/Projects/shakedracor/tei/pericles.xml
# /home/misinagy/Projects/shakedracor/tei/coriolanus.xml
# /home/misinagy/Projects/shakedracor/tei/the-merchant-of-venice.xml
# /home/misinagy/Projects/shakedracor/tei/macbeth.xml
# /home/misinagy/Projects/shakedracor/tei/julius-caesar.xml
# /home/misinagy/Projects/shakedracor/tei/henry-iv-part-1.xml
# /home/misinagy/Projects/shakedracor/tei/the-winters-tale.xml
# /home/misinagy/Projects/shakedracor/tei/henry-v.xml
# /home/misinagy/Projects/shakedracor/tei/much-ado-about-nothing.xml
# /home/misinagy/Projects/shakedracor/tei/henry-vi-part-1.xml
# /home/misinagy/Projects/shakedracor/tei/hamlet.xml
# /home/misinagy/Projects/shakedracor/tei/richard-iii.xml
# /home/misinagy/Projects/shakedracor/tei/antony-and-cleopatra.xml
# /home/misinagy/Projects/shakedracor/tei/richard-ii.xml
# /home/misinagy/Projects/shakedracor/tei/timon-of-athens.xml
# /home/misinagy/Projects/shakedracor/tei/troilus-and-cressida.xml
# /home/misinagy/Projects/shakedracor/tei/titus-andronicus.xml
# /home/misinagy/Projects/shakedracor/tei/romeo-and-juliet.xml
# /home/misinagy/Projects/shakedracor/tei/the-merry-wives-of-windsor.xml
# /home/misinagy/Projects/shakedracor/tei/cymbeline.xml
# /home/misinagy/Projects/shakedracor/tei/henry-vi-part-2.xml
# /home/misinagy/Projects/shakedracor/tei/henry-iv-part-2.xml
# /home/misinagy/Projects/shakedracor/tei/loves-labors-lost.xml
# /home/misinagy/Projects/shakedracor/tei/the-comedy-of-errors.xml
# /home/misinagy/Projects/shakedracor/tei/as-you-like-it.xml
# /home/misinagy/Projects/shakedracor/tei/king-lear.xml
# /home/misinagy/Projects/shakedracor/tei/henry-viii.xml
# /home/misinagy/Projects/shakedracor/tei/king-john.xml
# /home/misinagy/Projects/shakedracor/tei/twelfth-night.xml
# /home/misinagy/Projects/shakedracor/tei/othello.xml
# /home/misinagy/Projects/shakedracor/tei/alls-well-that-ends-well.xml
# /home/misinagy/Projects/shakedracor/tei/measure-for-measure.xml
# /home/misinagy/Projects/shakedracor/tei/henry-vi-part-3.xml

# %%
# get significant characters who have their own dialouge - THIS IS FOR FURTHER ANALYSIS, NOT FOR MATCHING WHOLE DRACORE NETWORK
significant_characters = []
for sp in shake_soups['coriolanus'].find_all('sp', {'who':True}):
    speakers = sp['who'].split(' ')
    if len(speakers) == 1 and speakers[0] not in significant_characters:
        significant_characters.extend(speakers)

# %%
# Iterate div type="act" tags and extract all characters, create combinations of 2 and add combination to list of edges
G_list = {}
for name, soup in shake_soups.items():
    edge_list = []
    lonely_nodes = []
    significant_characters = []
    for scene in soup.find_all('div', {'type': 'scene'}):
        scene_characters = []
        for sp in scene.find_all('sp', {'who': True}):
            speakers = sp['who'].split(' ')

            for split_sp in speakers:
                scene_characters.append(split_sp)
            
        if len(scene_characters) == 1:
            lonely_nodes.append(scene_characters[0])
            
        scene_edge_list = list(combinations(set(scene_characters), 2))
        edge_list += scene_edge_list
    
    whole = nx.from_edgelist(set(edge_list))
    
    for lonely_node in lonely_nodes:
        if lonely_node not in whole.nodes:
            whole.add_node(lonely_node)
    
    G_list[name] = {'whole': whole, 
                    'title_pretty': soup.find('title').get_text(strip=True), 
                    'kept_characters': ', '.join(list(whole.nodes())),
                    'character_count': len(whole.nodes()),
                   }
    

for name, soup in shake_soups.items():
    for n in [1,2,3,4,5]:
        lonely_nodes = []
        edge_list = []
    
        for act in soup.find_all('div', {'type': 'act'}):
            if act['n'] != str(n):
                for scene in act.find_all('div', {'type': 'scene'}):
                    scene_characters = []
                    for sp in scene.find_all('sp', {'who': True}):
                        speakers = sp['who'].split(' ')
                        
                        for split_sp in speakers:
                            scene_characters.append(split_sp)
                        scene_edge_list = list(combinations(set(scene_characters), 2))
                    if len(scene_characters) == 1:
                        lonely_nodes.append(scene_characters[0])
                    edge_list += scene_edge_list
        
        # create network from edge list
        whole = nx.from_edgelist(set(edge_list))
    
        # add those with independent scenes
        for lonely_node in lonely_nodes:
            if lonely_node not in whole.nodes:
                whole.add_node(lonely_node)
    
        G_list[name]['wo'+str(n)] = whole

# %% [markdown]
# **CSV WRITING**

# %%
csv_filename = 'shakedracore_metrics8.csv'
column_names = ['title', 'title_pretty', 'genre', 'kept_characters', 'character_count', 'removed_characters', 'removed_characters_count']
metric_names = ['density', 'diameter', 'average_clustering']
for w in ['whole', 'wo1', 'wo2', 'wo3', 'wo4', 'wo5']:
    for n in metric_names:
        column_names.append(w+'_'+n)

# %%
with open(csv_filename, 'w', newline='') as csvfile:
    fieldnames = column_names
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for name, graph_dict in G_list.items():
        drama_dict = {'title': name,
                      'title_pretty': graph_dict['title_pretty'],
                      'genre': SHAKESPEAR_GENRES[name],
                      'kept_characters': graph_dict['kept_characters'],
                      'character_count': graph_dict['character_count'],
#                       'removed_characters': graph_dict['removed_characters'],
#                       'removed_characters_count': graph_dict['removed_characters_count']
                     }
        
        drama_dict['whole_density'] = nx.density(graph_dict['whole'])
        drama_dict['whole_diameter'] = nx.diameter(get_largest_G(graph_dict['whole']))
        drama_dict['whole_average_clustering'] = nx.average_clustering(graph_dict['whole'])
        
        for w in ['wo1', 'wo2', 'wo3', 'wo4', 'wo5']:
            drama_dict[w+'_density'] = nx.density(graph_dict[w])
            drama_dict[w+'_diameter'] = nx.diameter(get_largest_G(graph_dict[w]))
            drama_dict[w+'_average_clustering'] = nx.average_clustering(graph_dict[w])
        
        
        writer.writerow(drama_dict)

# %% [markdown]
# **CUMULATIVE CALC**

# %%
cumulative_G_list = defaultdict(dict)

for name, soup in shake_soups.items():
    acts_included = []
    print(f'Analysising {name} acts', end='')
    for n in ['2','3','4','5']:  # deleted '1',
        acts_included.append(n)
        print(f'{acts_included[-1]} ', end='')
        lonely_nodes = []
        edge_list = []
        significant_characters = []
    
        for act in soup.find_all('div', {'type': 'act'}):
            # div type act has an attribute 'n' with value of act number.
            if act['n'] in acts_included:
                for scene in act.find_all('div', {'type': 'scene'}):
                    scene_characters = []
                    for sp in scene.find_all('sp', {'who': True}):
                        speakers = sp['who'].split(' ')
                        if len(speakers) == 1 and speakers[0] not in significant_characters:
                            significant_characters.extend(speakers)
                        for split_sp in speakers:
                            scene_characters.append(split_sp)
                        scene_edge_list = list(combinations(set(scene_characters), 2))
                    if len(scene_characters) == 1:
                        lonely_nodes.append(scene_characters[0])
                    edge_list += scene_edge_list
        
        # create network from edge list
        n_acts_whole = nx.from_edgelist(set(edge_list))
    
        # add those with independent scenes
        for lonely_node in lonely_nodes:
            if lonely_node not in n_acts_whole.nodes:
                n_acts_whole.add_node(lonely_node)
        
        cumulative_G_list[name]['title_pretty'] = soup.find('title').get_text(strip=True)
        cumulative_G_list[name][f"acts_{'-'.join(acts_included)}"] = n_acts_whole
# Out:
# Analysising a-midsummer-nights-dream acts2 3 4 5 Analysising the-tempest acts2 3 4 5 Analysising two-gentlemen-of-verona acts2 3 4 5 Analysising the-taming-of-the-shrew acts2 3 4 5 Analysising pericles acts2 3 4 5 Analysising coriolanus acts2 3 4 5 Analysising the-merchant-of-venice acts2 3 4 5 Analysising macbeth acts2 3 4 5 Analysising julius-caesar acts2 3 4 5 Analysising henry-iv-part-1 acts2 3 4 5 Analysising the-winters-tale acts2 3 4 5 Analysising henry-v acts2 3 4 5 Analysising much-ado-about-nothing acts2 3 4 5 Analysising henry-vi-part-1 acts2 3 4 5 Analysising hamlet acts2 3 4 5 Analysising richard-iii acts2 3 4 5 Analysising antony-and-cleopatra acts2 3 4 5 Analysising richard-ii acts2 3 4 5 Analysising timon-of-athens acts2 3 4 5 Analysising troilus-and-cressida acts2 3 4 5 Analysising titus-andronicus acts2 3 4 5 Analysising romeo-and-juliet acts2 3 4 5 Analysising the-merry-wives-of-windsor acts2 3 4 5 Analysising cymbeline acts2 3 4 5 Analysising henry-vi-part-2 acts2 3 4 5 Analysising henry-iv-part-2 acts2 3 4 5 Analysising loves-labors-lost acts2 3 4 5 Analysising the-comedy-of-errors acts2 3 4 5 Analysising as-you-like-it acts2 3 4 5 Analysising king-lear acts2 3 4 5 Analysising henry-viii acts2 3 4 5 Analysising king-john acts2 3 4 5 Analysising twelfth-night acts2 3 4 5 Analysising othello acts2 3 4 5 Analysising alls-well-that-ends-well acts2 3 4 5 Analysising measure-for-measure acts2 3 4 5 Analysising henry-vi-part-3 acts2 3 4 5

# %%
cumulative_G_list
# Out:
# defaultdict(dict,
#             {'a-midsummer-nights-dream': {'title_pretty': 'A Midsummer Night’s Dream',
#               'acts_2': <networkx.classes.graph.Graph at 0x786dc0d97f50>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786dc35d4da0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786dec64daf0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786de42842c0>},
#              'the-tempest': {'title_pretty': 'The Tempest',
#               'acts_2': <networkx.classes.graph.Graph at 0x786da1973140>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786dec10d4c0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786da0c2f9e0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786dec0db800>},
#              'two-gentlemen-of-verona': {'title_pretty': 'Two Gentlemen of Verona',
#               'acts_2': <networkx.classes.graph.Graph at 0x786dc352d4c0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786ded1ddcd0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786da7eda7b0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786dec61ade0>},
#              'the-taming-of-the-shrew': {'title_pretty': 'The Taming of the Shrew',
#               'acts_2': <networkx.classes.graph.Graph at 0x786dec61ac00>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786dec61b260>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786dd817f530>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96574f50>},
#              'pericles': {'title_pretty': 'Pericles',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965752b0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575370>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575310>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965754f0>},
#              'coriolanus': {'title_pretty': 'Coriolanus',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965752e0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575400>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575550>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96574e60>},
#              'the-merchant-of-venice': {'title_pretty': 'The Merchant of Venice',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965757c0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965751c0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575760>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575430>},
#              'macbeth': {'title_pretty': 'Macbeth',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96575850>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575790>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965758b0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575940>},
#              'julius-caesar': {'title_pretty': 'Julius Caesar',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965756d0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575670>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575a30>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575b50>},
#              'henry-iv-part-1': {'title_pretty': 'Henry IV, Part I',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96575be0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575d60>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575d00>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575e80>},
#              'the-winters-tale': {'title_pretty': "The Winter's Tale",
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96575c40>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575b20>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575eb0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575fa0>},
#              'henry-v': {'title_pretty': 'Henry V',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965759d0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576060>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96575b80>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965760f0>},
#              'much-ado-about-nothing': {'title_pretty': 'Much Ado About Nothing',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576900>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96575070>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965750a0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96575ac0>},
#              'henry-vi-part-1': {'title_pretty': 'Henry VI, Part 1',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965761b0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965762a0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96574e30>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576210>},
#              'hamlet': {'title_pretty': 'Hamlet',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576240>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576360>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965761e0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576180>},
#              'richard-iii': {'title_pretty': 'Richard III',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576330>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576390>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965763c0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576300>},
#              'antony-and-cleopatra': {'title_pretty': 'Antony and Cleopatra',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576600>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576510>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576630>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576570>},
#              'richard-ii': {'title_pretty': 'Richard II',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576780>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576720>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576870>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965766c0>},
#              'timon-of-athens': {'title_pretty': 'Timon of Athens',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965768d0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965766f0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965768a0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965764e0>},
#              'troilus-and-cressida': {'title_pretty': 'Troilus and Cressida',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576990>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576ae0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965762d0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965767b0>},
#              'titus-andronicus': {'title_pretty': 'Titus Andronicus',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576c30>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576a80>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576c00>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576b40>},
#              'romeo-and-juliet': {'title_pretty': 'Romeo and Juliet',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576690>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576c90>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576bd0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576cf0>},
#              'the-merry-wives-of-windsor': {'title_pretty': 'The Merry Wives of Windsor',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576a50>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576d20>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576ed0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96576d80>},
#              'cymbeline': {'title_pretty': 'Cymbeline',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576f60>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96576ba0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576c60>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965770b0>},
#              'henry-vi-part-2': {'title_pretty': 'Henry VI, Part 2',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577080>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577050>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96576db0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965771a0>},
#              'henry-iv-part-2': {'title_pretty': 'Henry IV, Part II',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96576f30>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577140>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577110>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965771d0>},
#              'loves-labors-lost': {'title_pretty': 'Love’s Labor’s Lost',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965774a0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965773b0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577230>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965772f0>},
#              'the-comedy-of-errors': {'title_pretty': 'The Comedy of Errors',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577410>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577500>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577170>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577470>},
#              'as-you-like-it': {'title_pretty': 'As You Like It',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577200>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965775f0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577290>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577560>},
#              'king-lear': {'title_pretty': 'King Lear',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965776b0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965774d0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965775c0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577710>},
#              'henry-viii': {'title_pretty': 'Henry VIII',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577650>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d965776e0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577740>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965779b0>},
#              'king-john': {'title_pretty': 'King John',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577a40>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577a10>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577530>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d965777d0>},
#              'twelfth-night': {'title_pretty': 'Twelfth Night',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d965778f0>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577b30>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d965778c0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577aa0>},
#              'othello': {'title_pretty': 'Othello',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577830>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577b00>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577bc0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577ad0>},
#              'alls-well-that-ends-well': {'title_pretty': 'All’s Well That Ends Well',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577c20>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577e00>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577c80>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577f20>},
#              'measure-for-measure': {'title_pretty': 'Measure for Measure',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577f50>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577fe0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577ef0>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577cb0>},
#              'henry-vi-part-3': {'title_pretty': 'Henry VI, Part 3',
#               'acts_2': <networkx.classes.graph.Graph at 0x786d96577d40>,
#               'acts_2-3': <networkx.classes.graph.Graph at 0x786d96577fb0>,
#               'acts_2-3-4': <networkx.classes.graph.Graph at 0x786d96577f80>,
#               'acts_2-3-4-5': <networkx.classes.graph.Graph at 0x786d96577770>}})

# %% [markdown]
# **CSV WRITING CUMULATIVE**

# %%
csv_filename = 'shakedracor_cumulative2.csv'
column_names = ['title', 'title_pretty', 'genre']
metric_names = ['density', 'diameter', 'average_clustering']
for w in ['acts_1', 'acts_1-2', 'acts_1-2-3', 'acts_1-2-3-4', 'acts_1-2-3-4-5']:
    for n in metric_names:
        column_names.append(w+'_'+n)

# %%
# just from 2
csv_filename = 'shakedracor_cumulative2.csv'
column_names = ['title', 'title_pretty', 'genre']
metric_names = ['density', 'diameter', 'average_clustering']
for w in ['acts_2', 'acts_2-3', 'acts_2-3-4', 'acts_2-3-4-5']:
    for n in metric_names:
        column_names.append(w+'_'+n)

# %%
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()
    
    for name, drama_data in cumulative_G_list.items():
        drama_dict = {'title': name,
              'title_pretty': drama_data['title_pretty'],
              'genre': SHAKESPEAR_GENRES[name],
             }
        for w in ['acts_1', 'acts_1-2', 'acts_1-2-3', 'acts_1-2-3-4', 'acts_1-2-3-4-5']:
            drama_dict[f'{w}_density'] = nx.density(drama_data[w])
            drama_dict[f'{w}_diameter'] = nx.diameter(get_largest_G(drama_data[w]))
            drama_dict[f'{w}_average_clustering'] = nx.average_clustering(drama_data[w])
        
        writer.writerow(drama_dict)

# %%
# just for from 2
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()
    
    for name, drama_data in cumulative_G_list.items():
        drama_dict = {'title': name,
              'title_pretty': drama_data['title_pretty'],
              'genre': SHAKESPEAR_GENRES[name],
             }
        for w in ['acts_2', 'acts_2-3', 'acts_2-3-4', 'acts_2-3-4-5']:
            drama_dict[f'{w}_density'] = nx.density(drama_data[w])
            drama_dict[f'{w}_diameter'] = nx.diameter(get_largest_G(drama_data[w]))
            drama_dict[f'{w}_average_clustering'] = nx.average_clustering(drama_data[w])
        
        writer.writerow(drama_dict)

# %% [markdown]
# **RESULTS**

# %%
# results
for name, G in G_list.items():
    print(f'{name:>15} DENSITY:', nx.density(G))
    print(f'{name:>15} DIAMETER:', nx.diameter(G_list_connected[name]))
    print(f'{name:>15} AVERAGE CLUSTERING:', nx.average_clustering(G), '\n')

# %% [markdown]
# <h3>GERMAN DRAMA ANALYSIS</h3>

# %% [markdown]
# **GERDRACORE CUMULATIVE**

# %%
# open xml files and parse soups
ger_soups = {}
for xml_path in Path(gerdracor_tei_files).glob('*.xml'):
    with open(xml_path, 'r') as fh:
        # Filter 5 act, 5+ actor, Tragedy and Comedy dramas from GerDracor
        soup = BeautifulSoup(fh.read(), 'lxml-xml')
        
        acts = soup.find_all('div', {'type': 'act'})
        cast_list = soup.find('profileDesc').find('listPerson').find_all('person')
        genre_tag = soup.find('textClass').find('keywords').find('term', {'type': 'genreTitle'})
        genre = genre_tag.get_text(strip=True)
        if cast_list is None:
            raise ValueError('No cast list found!')
        if len(acts) == 5 and len(cast_list) > 5 and genre in ['Tragedy', 'Comedy']:
            ger_soups[xml_path.stem] = soup

# %%
s = ger_soups['sudermann-der-bettler-von-syrakus']
divs = s.body.find_all('div', recursive=False)
print(len(divs))
# len(divs[1].find_all('div', recursive=False))
# divs[1].find_all('div', recursive=False)[2]
len(s.find_all('div', {'type': 'act'}))
# Out:
# 6
# 5

# %%
# sudermann-der-bettler-von-syrakus
# hebbel-der-diamant
# schiller-die-jungfrau-von-orleans
# hauptmann-florian-geyer
# laube-monaldeschi

for name, soup in ger_soups.items():
    
    all_divs = len(soup.body.find_all('div', recursive=False))
    
    all_acts = len(soup.find_all('div', {'type': 'act'}))
    prologue = soup.find_all('div', {'type': 'prologue'})
    epilogue = soup.find_all('div', {'type': 'epilogue'})
    
    print(name, (50-len(name))*' ', all_divs, all_acts)
# Out:
# grillparzer-des-meeres-und-der-liebe-wellen         5 5
# goethe-clavigo                                      5 5
# grillparzer-medea                                   5 5
# hauptmann-carl-tobias-buntschuh                     5 5
# ludwig-die-makkabaeer                               5 5
# toerring-agnes-bernauerin                           5 5
# beer-struensee                                      5 5
# hofmannsthal-der-turm                               5 5
# wieland-lady-johanna-gray                           5 5
# gottschedin-das-testament                           5 5
# laube-gottsched-und-gellert                         5 5
# immermann-andreas-hofer                             5 5
# gryphius-catharina-von-georgien                     5 5
# collin-coriolan                                     5 5
# goethe-der-grosskophta                              5 5
# hebbel-judith                                       5 5
# grabbe-kaiser-heinrich-der-sechste                  5 5
# klinger-das-leidende-weib                           5 5
# pfeil-lucie-woodvil                                 5 5
# cronegk-der-misstrauische                           5 5
# hebbel-herodes-und-mariamne                         5 5
# kotzebue-der-wirrwarr                               6 5
# gryphius-papinianus                                 5 5
# muellner-koenig-yngurd                              5 5
# hebbel-siegfrieds-tod                               5 5
# brentano-ponce-de-leon                              6 5
# iffland-figaro-in-deutschland                       5 5
# holz-sozialaristokraten                             5 5
# goethe-die-natuerliche-tochter                      5 5
# leisewitz-julius-von-tarent                         5 5
# schnitzler-professor-bernhardi                      5 5
# eichendorff-der-letzte-held-von-marienburg          5 5
# goethe-faust-der-tragoedie-zweiter-teil             5 5
# schiller-die-verschwoerung-des-fiesco-zu-genua      5 5
# sudermann-der-bettler-von-syrakus                   6 5
# hartleben-rosenmontag                               5 5
# bleibtreu-weltgericht                               2 5
# klingemann-faust                                    5 5
# quistorp-der-hypochondrist                          5 5
# panizza-das-liebeskonzil                            5 5
# voss-faust                                          5 5
# koerner-zriny                                       5 5
# hebbel-gyges-und-sein-ring                          5 5
# gryphius-leo-armenius-oder-fuersten-mord            5 5
# seume-miltiades                                     5 5
# braun-von-braunthal-faust                           5 5
# platen-der-romantische-oedipus                      6 5
# hebbel-der-diamant                                  7 5
# laube-struensee                                     5 5
# kotzebue-die-spanier-in-peru                        5 5
# grillparzer-ein-bruderzwist-in-habsburg             5 5
# sturz-julie                                         5 5
# grabbe-herzog-theodor-von-gothland                  5 5
# lassalle-franz-von-sickingen                        5 5
# brawe-brutus                                        5 5
# lenz-der-neue-menoza                                5 5
# gottsched-der-sterbende-cato                        5 5
# hofmannsthal-der-unbestechliche                     5 5
# grillparzer-koenig-ottokars-glueck-und-ende         5 5
# braun-mutter-maria                                  5 5
# lessing-minna-von-barnhelm                          5 5
# dehmel-michel-michael                               6 5
# krueger-die-candidaten                              5 5
# schiller-maria-stuart                               5 5
# lenz-die-freunde-machen-den-philosophen             5 5
# schiller-kabale-und-liebe                           5 5
# gryphius-horribilicribrifax-teutsch                 6 5
# heiseler-die-kinder-godunofs                        5 5
# hebbel-genoveva                                     6 5
# neuber-das-schaeferfest                             6 5
# grillparzer-ein-treuer-diener-seines-herrn          5 5
# schiller-die-jungfrau-von-orleans                   6 5
# gryphius-carolus-stuardus                           5 5
# ludwig-der-erbfoerster                              5 5
# gottschedin-die-pietisterey-im-fischbein-rocke      5 5
# lessing-emilia-galotti                              5 5
# gryphius-cardenio-und-celinde                       5 5
# scheerbart-es-lebe-europa                           5 5
# holz-sonnenfinsternis                               5 5
# hebbel-agnes-bernauer                               5 5
# lenz-der-hofmeister                                 5 5
# gutzkow-richard-savage                              5 5
# kraus-die-letzten-tage-der-menschheit               7 5
# hebbel-kriemhilds-rache                             5 5
# kotzebue-pagenstreiche                              5 5
# grabbe-kaiser-friedrich-barbarossa                  5 5
# cronegk-codrus                                      5 5
# grillparzer-die-ahnfrau                             5 5
# immermann-das-gericht-von-st-petersburg             5 5
# panizza-nero                                        5 5
# wildgans-armut                                      5 5
# lessing-der-freigeist                               5 5
# essig-ueberteufel                                   5 5
# wilbrandt-gracchus-der-volkstribun                  5 5
# goethe-egmont                                       5 5
# hauptmann-florian-geyer                             6 5
# heyse-don-juans-ende                                5 5
# grillparzer-die-juedin-von-toledo                   5 5
# brachvogel-narziss                                  5 5
# klinger-die-zwillinge                               5 5
# gutzkow-zopf-und-schwert                            5 5
# scheerbart-okurirasuna                              5 5
# grillparzer-libussa                                 5 5
# schlegel-der-triumph-der-guten-frauen               5 5
# essig-der-frauenmut                                 5 5
# grillparzer-sappho                                  5 5
# schiller-wallensteins-tod                           5 5
# weissenthurn-das-manuscript                         5 5
# brawe-der-freigeist                                 5 5
# lessing-miss-sara-sampson                           5 5
# tieck-karl-von-berneck                              5 5
# gutzkow-das-urbild-des-tartueffe                    5 5
# gutzkow-uriel-acosta                                5 5
# schlegel-der-geschaeftige-muessiggaenger            5 5
# heiseler-peter-und-alexej                           5 5
# weissenthurn-welche-ist-die-braut                   5 5
# holz-ignorabimus                                    5 5
# grillparzer-weh-dem-der-luegt                       5 5
# wildgans-dies-irae                                  5 5
# laube-monaldeschi                                   6 5
# engel-eid-und-pflicht                               5 5
# schlegel-canut                                      5 5
# anonym-der-deutsche-student                         5 5
# platen-die-verhaengnisvolle-gabel                   6 5
# uhland-ernst-herzog-von-schwaben                    5 5
# bleibtreu-ein-faust-der-that                        5 5
# scheerbart-herr-kammerdiener-kneetschke             5 5
# kleist-die-familie-schroffenstein                   5 5

# %%
def one_appearance_unit_edge_list(unit, lonely_nodes):
    """
    Take unit of BS4 tag and extract all connections between speakers in unit.
    """
    characters = []
                
    for sp in unit.find_all('sp', {'who': True}):
        # get each speaker from speaker tag
        speakers = sp['who'].split(' ')

        for split_sp in speakers:
            characters.append(split_sp)
    edge_list = list(combinations(set(characters), 2))
    # if only one character in scene, add lonely node
    if len(characters) == 1:
        lonely_nodes.append(characters[0])
    
    return edge_list, lonely_nodes

# %%
# CREATE THE MAIN EXTRACTOR FUNCTION
# take first n acts from drama
def edge_list_extractor_extractor(list_of_soup_segments):
    """
    Takes list of soup elements, returns edge list for shared scenes, and if no scenes, just shared acts.
    This is GerDracor specific, and should only be used for the 128 dramas --> len(acts) == 5 and len(cast_list) > 5 and genre in ['Tragedy', 'Comedy']
    """
    
    lonely_nodes = []
    edge_list_in_iteration = []

    # iterate over n acts
    for c, act in enumerate(list_of_soup_segments, start=1):
        if act is None:
            if c == 1 or c == len(list_of_soup_segments):
                continue
            else:
                raise ValueError(f'ACT {c} IS NONE IN {name}')
                
        configurations_in_act = act.find_all('div', {'type': 'configuration'})
        locations_in_act = act.find_all('div', {'type': 'location'})
        scenes_in_act = act.find_all('div', {'type': 'scene'})
        
        check_list = [len(configurations_in_act) > 0, len(locations_in_act) > 0, len(scenes_in_act) > 0]
        if len([c for c in check_list if c is True]) > 1:
            raise ValueError(f'UNACCOUNTED STRUCTURE OF DRAMA - {name} ! {check_list}')
        
        # IF IT HAS SCENES
        if len(scenes_in_act) > 0:
            for scene in scenes_in_act:
                if scene.find('div', {'type': 'scene'}) is not None:
                    for inner_scene in scene.find_all('div', {'type': 'scene'}):
                        if inner_scene.find('div', {'type': 'scene'}):
                            print(f'SCENE WITHIN SCENE WITHIN SCENE in {name}', file=sys.stderr)
                        scene_edge_list, lonely_nodes = one_appearance_unit_edge_list(inner_scene, lonely_nodes)
                        edge_list_in_iteration += scene_edge_list
                else:
                    scene_edge_list, lonely_nodes = one_appearance_unit_edge_list(scene, lonely_nodes)
                    edge_list_in_iteration += scene_edge_list

        # IT HAS LOCATIONS
        elif len(locations_in_act) > 0:
            for location in locations_in_act:
                    
                location_edge_list, lonely_nodes = one_appearance_unit_edge_list(location, lonely_nodes)
                edge_list_in_iteration += location_edge_list
        
        # IT HAS CONFIGURATIONS
        elif len(configurations_in_act) > 0:
            for configuration in configurations_in_act:
                configuration_edge_list, lonely_nodes = one_appearance_unit_edge_list(configuration, lonely_nodes)
                edge_list_in_iteration += configuration_edge_list
        
        # IT HAS NO SCENES AND NO LOCATIONS AND NO CONFIGURATIONS
        else:
            if act.find('div') is not None:
                raise ValueError(f'Unaccounted div type in {name} !')
            act_edge_list, lonely_nodes = one_appearance_unit_edge_list(act, lonely_nodes)
            edge_list_in_iteration += act_edge_list

    return edge_list_in_iteration, lonely_nodes

# %%
# TEST
# sudermann-der-bettler-von-syrakus
# hebbel-der-diamant
# schiller-die-jungfrau-von-orleans
# hauptmann-florian-geyer
# laube-monaldeschi

# %%
# MAIN CUMULATIVE NETWORKS GENERATION FOR GERDRACOR

cumulative_G_list_ger = defaultdict(dict)

for name, soup in ger_soups.items():
    
    # Metadata annotation for dict
    cumulative_G_list_ger[name]['soup'] = soup
    genre_tag = soup.find('textClass').find('keywords').find('term', {'type': 'genreTitle'})
    cumulative_G_list_ger[name]['genre'] = genre_tag.get_text(strip=True)
    cumulative_G_list_ger[name]['title_pretty'] = soup.find('title').get_text(strip=True)
    
    # These are used to determine what structural elements there are.
    all_acts = soup.find_all('div', {'type': 'act'})
    prologue = soup.find('div', {'type': 'prologue'})
    epilogue = soup.find('div', {'type': 'epilogue'})
    
    # Whole calculation to 
    whole_list = []
    whole_list.extend(all_acts)
    
    if prologue is not None:
        whole_list.insert(0, prologue)
    elif prologue is None:
        whole_list.insert(0, None)
    
    if epilogue is not None:
        whole_list.append(epilogue)
    elif epilogue is None:
        whole_list.append(None)
        
    edge_list, lonely_nodes = edge_list_extractor_extractor(whole_list)
    # create network from edge list
    whole_drama = nx.from_edgelist(set(edge_list))

    # add those with independent scenes
    for lonely_node in lonely_nodes:
        if lonely_node not in whole_drama.nodes:
            whole_drama.add_node(lonely_node)
    
    cumulative_G_list_ger[name]['whole'] = whole_drama
    
    # Culminative calculation
    print(f'Processing {name}', (50-(len(name)))*' ', end='')
    # create iterations for 1, 1-2, 1-2-3, ... acts
    for iteration_round in range(1, len(whole_list)+1):  # was all_acts
        
        # take first n acts from drama
        acts_included = whole_list[:iteration_round]  # was all_acts
        print(f'-{len(acts_included)}', end='')
        
        edge_list_in_iteration, lonely_nodes = edge_list_extractor_extractor(acts_included)

        # create network from edge list
        n_acts_whole = nx.from_edgelist(set(edge_list_in_iteration))

        # add those with independent scenes
        for lonely_node in lonely_nodes:
            if lonely_node not in n_acts_whole.nodes:
                n_acts_whole.add_node(lonely_node)
        
        if iteration_round == 1:
            label = 'epilogue'
            if whole_list[0] is None:
                n_acts_whole = None
        elif iteration_round == len(whole_list):
            label = 'prologue'
            if whole_list[-1] is None:
                n_acts_whole = None
        else:
            label = f"acts_{'-'.join([str(i) for i in range(1, iteration_round)])}"
            
        cumulative_G_list_ger[name][label] = n_acts_whole
    print('\n---------------')
# Out:
# Processing grillparzer-des-meeres-und-der-liebe-wellen        -1-2-3-4-5-6-7
# ---------------
# Processing goethe-clavigo                                     -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-medea                                  -1-2-3-4-5-6-7
# ---------------
# Processing hauptmann-carl-tobias-buntschuh                    -1-2-3-4-5-6-7
# ---------------
# Processing ludwig-die-makkabaeer                              -1-2-3-4-5-6-7
# ---------------
# Processing toerring-agnes-bernauerin                          -1-2-3-4-5-6-7
# ---------------
# Processing beer-struensee                                     -1-2-3-4-5-6-7
# ---------------
# Processing hofmannsthal-der-turm                              -1-2-3-4-5-6-7
# ---------------
# Processing wieland-lady-johanna-gray                          -1-2-3-4-5-6-7
# ---------------
# Processing gottschedin-das-testament                          -1-2-3-4-5-6-7
# ---------------
# Processing laube-gottsched-und-gellert                        -1-2-3-4-5-6-7
# ---------------
# Processing immermann-andreas-hofer                            -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-catharina-von-georgien                    -1-2-3-4-5-6-7
# ---------------
# Processing collin-coriolan                                    -1-2-3-4-5-6-7
# ---------------
# Processing goethe-der-grosskophta                             -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-judith                                      -1-2-3-4-5-6-7
# ---------------
# Processing grabbe-kaiser-heinrich-der-sechste                 -1-2-3-4-5-6-7
# ---------------
# Processing klinger-das-leidende-weib                          -1-2-3-4-5-6-7
# ---------------
# Processing pfeil-lucie-woodvil                                -1-2-3-4-5-6-7
# ---------------
# Processing cronegk-der-misstrauische                          -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-herodes-und-mariamne                        -1-2-3-4-5-6-7
# ---------------
# Processing kotzebue-der-wirrwarr                              -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-papinianus                                -1-2-3-4-5-6-7
# ---------------
# Processing muellner-koenig-yngurd                             -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-siegfrieds-tod                              -1-2-3-4-5-6-7
# ---------------
# Processing brentano-ponce-de-leon                             -1-2-3-4-5-6-7
# ---------------
# Processing iffland-figaro-in-deutschland                      -1-2-3-4-5-6-7
# ---------------
# Processing holz-sozialaristokraten                            -1-2-3-4-5-6-7
# ---------------
# Processing goethe-die-natuerliche-tochter                     -1-2-3-4-5-6-7
# ---------------
# Processing leisewitz-julius-von-tarent                        -1-2-3-4-5-6-7
# ---------------
# Processing schnitzler-professor-bernhardi                     -1-2-3-4-5-6-7
# ---------------
# Processing eichendorff-der-letzte-held-von-marienburg         -1-2-3-4-5-6-7
# ---------------
# Processing goethe-faust-der-tragoedie-zweiter-teil            -1-2-3-4-5-6-7
# ---------------
# Processing schiller-die-verschwoerung-des-fiesco-zu-genua     -1-2-3-4-5-6-7
# ---------------
# Processing sudermann-der-bettler-von-syrakus                  -1-2-3-4-5-6-7
# ---------------
# Processing hartleben-rosenmontag                              -1-2-3-4-5-6-7
# ---------------
# Processing bleibtreu-weltgericht                              -1-2-3-4-5-6-7
# ---------------
# Processing klingemann-faust                                   -1-2-3-4-5-6-7
# ---------------
# Processing quistorp-der-hypochondrist                         -1-2-3-4-5-6-7
# ---------------
# Processing panizza-das-liebeskonzil                           -1-2-3-4-5-6-7
# ---------------
# Processing voss-faust                                         -1-2-3-4-5-6-7
# ---------------
# Processing koerner-zriny                                      -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-gyges-und-sein-ring                         -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-leo-armenius-oder-fuersten-mord           -1-2-3-4-5-6-7
# ---------------
# Processing seume-miltiades                                    -1-2-3-4-5-6-7
# ---------------
# Processing braun-von-braunthal-faust                          -1-2-3-4-5-6-7
# ---------------
# Processing platen-der-romantische-oedipus                     -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-der-diamant                                 -1-2-3-4-5-6-7
# ---------------
# Processing laube-struensee                                    -1-2-3-4-5-6-7
# ---------------
# Processing kotzebue-die-spanier-in-peru                       -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-ein-bruderzwist-in-habsburg            -1-2-3-4-5-6-7
# ---------------
# Processing sturz-julie                                        -1-2-3-4-5-6-7
# ---------------
# Processing grabbe-herzog-theodor-von-gothland                 -1-2-3-4-5-6-7
# ---------------
# Processing lassalle-franz-von-sickingen                       -1-2-3-4-5-6-7
# ---------------
# Processing brawe-brutus                                       -1-2-3-4-5-6-7
# ---------------
# Processing lenz-der-neue-menoza                               -1-2-3-4-5-6-7
# ---------------
# Processing gottsched-der-sterbende-cato                       -1-2-3-4-5-6-7
# ---------------
# Processing hofmannsthal-der-unbestechliche                    -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-koenig-ottokars-glueck-und-ende        -1-2-3-4-5-6-7
# ---------------
# Processing braun-mutter-maria                                 -1-2-3-4-5-6-7
# ---------------
# Processing lessing-minna-von-barnhelm                         -1-2-3-4-5-6-7
# ---------------
# Processing dehmel-michel-michael                              -1-2-3-4-5-6-7
# ---------------
# Processing krueger-die-candidaten                             -1-2-3-4-5-6-7
# ---------------
# Processing schiller-maria-stuart                              -1-2-3-4-5-6-7
# ---------------
# Processing lenz-die-freunde-machen-den-philosophen            -1-2-3-4-5-6-7
# ---------------
# Processing schiller-kabale-und-liebe                          -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-horribilicribrifax-teutsch                -1-2-3-4-5-6-7
# ---------------
# Processing heiseler-die-kinder-godunofs                       -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-genoveva                                    -1-2-3-4-5-6-7
# ---------------
# Processing neuber-das-schaeferfest                            -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-ein-treuer-diener-seines-herrn         -1-2-3-4-5-6-7
# ---------------
# Processing schiller-die-jungfrau-von-orleans                  -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-carolus-stuardus                          -1-2-3-4-5-6-7
# ---------------
# Processing ludwig-der-erbfoerster                             -1-2-3-4-5-6-7
# ---------------
# Processing gottschedin-die-pietisterey-im-fischbein-rocke     -1-2-3-4-5-6-7
# ---------------
# Processing lessing-emilia-galotti                             -1-2-3-4-5-6-7
# ---------------
# Processing gryphius-cardenio-und-celinde                      -1-2-3-4-5-6-7
# ---------------
# Processing scheerbart-es-lebe-europa                          -1-2-3-4-5-6-7
# ---------------
# Processing holz-sonnenfinsternis                              -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-agnes-bernauer                              -1-2-3-4-5-6-7
# ---------------
# Processing lenz-der-hofmeister                                -1-2-3-4-5-6-7
# ---------------
# Processing gutzkow-richard-savage                             -1-2-3-4-5-6-7
# ---------------
# Processing kraus-die-letzten-tage-der-menschheit              -1-2-3-4-5-6-7
# ---------------
# Processing hebbel-kriemhilds-rache                            -1-2-3-4-5-6-7
# ---------------
# Processing kotzebue-pagenstreiche                             -1-2-3-4-5-6-7
# ---------------
# Processing grabbe-kaiser-friedrich-barbarossa                 -1-2-3-4-5-6-7
# ---------------
# Processing cronegk-codrus                                     -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-die-ahnfrau                            -1-2-3-4-5-6-7
# ---------------
# Processing immermann-das-gericht-von-st-petersburg            -1-2-3-4-5-6-7
# ---------------
# Processing panizza-nero                                       -1-2-3-4-5-6-7
# ---------------
# Processing wildgans-armut                                     -1-2-3-4-5-6-7
# ---------------
# Processing lessing-der-freigeist                              -1-2-3-4-5-6-7
# ---------------
# Processing essig-ueberteufel                                  -1-2-3-4-5-6-7
# ---------------
# Processing wilbrandt-gracchus-der-volkstribun                 -1-2-3-4-5-6-7
# ---------------
# Processing goethe-egmont                                      -1-2-3-4-5-6-7
# ---------------
# Processing hauptmann-florian-geyer                            -1-2-3-4-5-6-7
# ---------------
# Processing heyse-don-juans-ende                               -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-die-juedin-von-toledo                  -1-2-3-4-5-6-7
# ---------------
# Processing brachvogel-narziss                                 -1-2-3-4-5-6-7
# ---------------
# Processing klinger-die-zwillinge                              -1-2-3-4-5-6-7
# ---------------
# Processing gutzkow-zopf-und-schwert                           -1-2-3-4-5-6-7
# ---------------
# Processing scheerbart-okurirasuna                             -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-libussa                                -1-2-3-4-5-6-7
# ---------------
# Processing schlegel-der-triumph-der-guten-frauen              -1-2-3-4-5-6-7
# ---------------
# Processing essig-der-frauenmut                                -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-sappho                                 -1-2-3-4-5-6-7
# ---------------
# Processing schiller-wallensteins-tod                          -1-2-3-4-5-6-7
# ---------------
# Processing weissenthurn-das-manuscript                        -1-2-3-4-5-6-7
# ---------------
# Processing brawe-der-freigeist                                -1-2-3-4-5-6-7
# ---------------
# Processing lessing-miss-sara-sampson                          -1-2-3-4-5-6-7
# ---------------
# Processing tieck-karl-von-berneck                             -1-2-3-4-5-6-7
# ---------------
# Processing gutzkow-das-urbild-des-tartueffe                   -1-2-3-4-5-6-7
# ---------------
# Processing gutzkow-uriel-acosta                               -1-2-3-4-5-6-7
# ---------------
# Processing schlegel-der-geschaeftige-muessiggaenger           -1-2-3-4-5-6-7
# ---------------
# Processing heiseler-peter-und-alexej                          -1-2-3-4-5-6-7
# ---------------
# Processing weissenthurn-welche-ist-die-braut                  -1-2-3-4-5-6-7
# ---------------
# Processing holz-ignorabimus                                   -1-2-3-4-5-6-7
# ---------------
# Processing grillparzer-weh-dem-der-luegt                      -1-2-3-4-5-6-7
# ---------------
# Processing wildgans-dies-irae                                 -1-2-3-4-5-6-7
# ---------------
# Processing laube-monaldeschi                                  -1-2-3-4-5-6-7
# ---------------
# Processing engel-eid-und-pflicht                              -1-2-3-4-5-6-7
# ---------------
# Processing schlegel-canut                                     -1-2-3-4-5-6-7
# ---------------
# Processing anonym-der-deutsche-student                        -1-2-3-4-5-6-7
# ---------------
# Processing platen-die-verhaengnisvolle-gabel                  -1-2-3-4-5-6-7
# ---------------
# Processing uhland-ernst-herzog-von-schwaben                   -1-2-3-4-5-6-7
# ---------------
# Processing bleibtreu-ein-faust-der-that                       -1-2-3-4-5-6-7
# ---------------
# Processing scheerbart-herr-kammerdiener-kneetschke            -1-2-3-4-5-6-7
# ---------------
# Processing kleist-die-familie-schroffenstein                  -1-2-3-4-5-6-7
# ---------------

# %%
# MAIN CUMULATIVE NETWORKS GENERATION FOR GERDRACOR WITHOUT EPILOGUE AND PROLOGUE

cumulative_G_list_ger = defaultdict(dict)

for name, soup in ger_soups.items():

    # Metadata annotation for dict
    cumulative_G_list_ger[name]['soup'] = soup
    genre_tag = soup.find('textClass').find('keywords').find('term', {'type': 'genreTitle'})
    cumulative_G_list_ger[name]['genre'] = genre_tag.get_text(strip=True)
    cumulative_G_list_ger[name]['title_pretty'] = soup.find('title').get_text(strip=True)
    
    # These are used to determine what structural elements there are.
    all_acts = soup.find_all('div', {'type': 'act'})
        
    edge_list, lonely_nodes = edge_list_extractor_extractor(all_acts)
    # create network from edge list
    whole_drama = nx.from_edgelist(set(edge_list))

    # add those with independent scenes
    for lonely_node in lonely_nodes:
        if lonely_node not in whole_drama.nodes:
            whole_drama.add_node(lonely_node)
    
    cumulative_G_list_ger[name]['whole'] = whole_drama
    
    # Culminative calculation
    print(f'Processing {name}', (50-(len(name)))*' ', end='\n')
    # create iterations for 1, 1-2, 1-2-3, ... acts
    for iteration_round in range(1, len(all_acts)+1):
        
        # take first n acts from drama
        acts_included = all_acts[:iteration_round] 
        # print(f'-{len(acts_included)}', end='')
        
        edge_list_in_iteration, lonely_nodes = edge_list_extractor_extractor(acts_included)

        # create network from edge list
        print(name, len(set(edge_list_in_iteration)))
        n_acts_whole = nx.from_edgelist(set(edge_list_in_iteration))

        # add those with independent scenes
        for lonely_node in lonely_nodes:
            if lonely_node not in n_acts_whole.nodes:
                n_acts_whole.add_node(lonely_node)
        
        label = f"acts_{'-'.join([str(i) for i in range(1, iteration_round+1)])}"    
        
        cumulative_G_list_ger[name][label] = n_acts_whole
    print('\n---------------')
# Out:
# Processing grillparzer-des-meeres-und-der-liebe-wellen
# grillparzer-des-meeres-und-der-liebe-wellen 55
# grillparzer-des-meeres-und-der-liebe-wellen 55
# grillparzer-des-meeres-und-der-liebe-wellen 55
# grillparzer-des-meeres-und-der-liebe-wellen 55
# grillparzer-des-meeres-und-der-liebe-wellen 55
#
# ---------------
# Processing goethe-clavigo
# goethe-clavigo 21
# goethe-clavigo 28
# goethe-clavigo 28
# goethe-clavigo 28
# goethe-clavigo 38
#
# ---------------
# Processing grillparzer-medea
# grillparzer-medea 28
# grillparzer-medea 32
# grillparzer-medea 32
# grillparzer-medea 43
# grillparzer-medea 47
#
# ---------------
# Processing hauptmann-carl-tobias-buntschuh
# hauptmann-carl-tobias-buntschuh 6
# hauptmann-carl-tobias-buntschuh 18
# hauptmann-carl-tobias-buntschuh 59
# hauptmann-carl-tobias-buntschuh 64
# hauptmann-carl-tobias-buntschuh 66
#
# ---------------
# Processing ludwig-die-makkabaeer
# ludwig-die-makkabaeer 78
# ludwig-die-makkabaeer 178
# ludwig-die-makkabaeer 355
# ludwig-die-makkabaeer 374
# ludwig-die-makkabaeer 403
#
# ---------------
# Processing toerring-agnes-bernauerin
# toerring-agnes-bernauerin 50
# toerring-agnes-bernauerin 93
# toerring-agnes-bernauerin 105
# toerring-agnes-bernauerin 112
# toerring-agnes-bernauerin 134
#
# ---------------
# Processing beer-struensee
# beer-struensee 32
# beer-struensee 77
# beer-struensee 122
# beer-struensee 202
# beer-struensee 207
#
# ---------------
# Processing hofmannsthal-der-turm
# hofmannsthal-der-turm 34
# hofmannsthal-der-turm 191
# hofmannsthal-der-turm 395
# hofmannsthal-der-turm 1170
# hofmannsthal-der-turm 1472
#
# ---------------
# Processing wieland-lady-johanna-gray
# wieland-lady-johanna-gray 4
# wieland-lady-johanna-gray 16
# wieland-lady-johanna-gray 20
# wieland-lady-johanna-gray 23
# wieland-lady-johanna-gray 26
#
# ---------------
# Processing gottschedin-das-testament
# gottschedin-das-testament 7
# gottschedin-das-testament 15
# gottschedin-das-testament 18
# gottschedin-das-testament 23
# gottschedin-das-testament 49
#
# ---------------
# Processing laube-gottsched-und-gellert
# laube-gottsched-und-gellert 23
# laube-gottsched-und-gellert 48
# laube-gottsched-und-gellert 59
# laube-gottsched-und-gellert 62
# laube-gottsched-und-gellert 113
#
# ---------------
# Processing immermann-andreas-hofer
# immermann-andreas-hofer 36
# immermann-andreas-hofer 77
# immermann-andreas-hofer 80
# immermann-andreas-hofer 107
# immermann-andreas-hofer 112
#
# ---------------
# Processing gryphius-catharina-von-georgien
# gryphius-catharina-von-georgien 8
# gryphius-catharina-von-georgien 12
# gryphius-catharina-von-georgien 13
# gryphius-catharina-von-georgien 42
# gryphius-catharina-von-georgien 53
#
# ---------------
# Processing collin-coriolan
# collin-coriolan 6
# collin-coriolan 36
# collin-coriolan 49
# collin-coriolan 53
# collin-coriolan 56
#
# ---------------
# Processing goethe-der-grosskophta
# goethe-der-grosskophta 49
# goethe-der-grosskophta 67
# goethe-der-grosskophta 83
# goethe-der-grosskophta 84
# goethe-der-grosskophta 118
#
# ---------------
# Processing hebbel-judith
# hebbel-judith 66
# hebbel-judith 69
# hebbel-judith 445
# hebbel-judith 459
# hebbel-judith 635
#
# ---------------
# Processing grabbe-kaiser-heinrich-der-sechste
# grabbe-kaiser-heinrich-der-sechste 83
# grabbe-kaiser-heinrich-der-sechste 210
# grabbe-kaiser-heinrich-der-sechste 341
# grabbe-kaiser-heinrich-der-sechste 419
# grabbe-kaiser-heinrich-der-sechste 494
#
# ---------------
# Processing klinger-das-leidende-weib
# klinger-das-leidende-weib 74
# klinger-das-leidende-weib 80
# klinger-das-leidende-weib 82
# klinger-das-leidende-weib 86
# klinger-das-leidende-weib 94
#
# ---------------
# Processing pfeil-lucie-woodvil
# pfeil-lucie-woodvil 8
# pfeil-lucie-woodvil 16
# pfeil-lucie-woodvil 18
# pfeil-lucie-woodvil 21
# pfeil-lucie-woodvil 23
#
# ---------------
# Processing cronegk-der-misstrauische
# cronegk-der-misstrauische 12
# cronegk-der-misstrauische 17
# cronegk-der-misstrauische 22
# cronegk-der-misstrauische 26
# cronegk-der-misstrauische 26
#
# ---------------
# Processing hebbel-herodes-und-mariamne
# hebbel-herodes-und-mariamne 21
# hebbel-herodes-und-mariamne 44
# hebbel-herodes-und-mariamne 55
# hebbel-herodes-und-mariamne 75
# hebbel-herodes-und-mariamne 112
#
# ---------------
# Processing kotzebue-der-wirrwarr
# kotzebue-der-wirrwarr 18
# kotzebue-der-wirrwarr 25
# kotzebue-der-wirrwarr 30
# kotzebue-der-wirrwarr 31
# kotzebue-der-wirrwarr 40
#
# ---------------
# Processing gryphius-papinianus
# gryphius-papinianus 3
# gryphius-papinianus 29
# gryphius-papinianus 36
# gryphius-papinianus 49
# gryphius-papinianus 81
#
# ---------------
# Processing muellner-koenig-yngurd
# muellner-koenig-yngurd 41
# muellner-koenig-yngurd 92
# muellner-koenig-yngurd 136
# muellner-koenig-yngurd 161
# muellner-koenig-yngurd 201
#
# ---------------
# Processing hebbel-siegfrieds-tod
# hebbel-siegfrieds-tod 16
# hebbel-siegfrieds-tod 40
# hebbel-siegfrieds-tod 51
# hebbel-siegfrieds-tod 65
# hebbel-siegfrieds-tod 97
#
# ---------------
# Processing brentano-ponce-de-leon
# brentano-ponce-de-leon 41
# brentano-ponce-de-leon 53
# brentano-ponce-de-leon 80
# brentano-ponce-de-leon 91
# brentano-ponce-de-leon 171
#
# ---------------
# Processing iffland-figaro-in-deutschland
# iffland-figaro-in-deutschland 33
# iffland-figaro-in-deutschland 73
# iffland-figaro-in-deutschland 92
# iffland-figaro-in-deutschland 104
# iffland-figaro-in-deutschland 117
#
# ---------------
# Processing holz-sozialaristokraten
# holz-sozialaristokraten 21
# holz-sozialaristokraten 51
# holz-sozialaristokraten 85
# holz-sozialaristokraten 92
# holz-sozialaristokraten 92
#
# ---------------
# Processing goethe-die-natuerliche-tochter
# goethe-die-natuerliche-tochter 9
# goethe-die-natuerliche-tochter 12
# goethe-die-natuerliche-tochter 15
# goethe-die-natuerliche-tochter 18
# goethe-die-natuerliche-tochter 23
#
# ---------------
# Processing leisewitz-julius-von-tarent
# leisewitz-julius-von-tarent 7
# leisewitz-julius-von-tarent 12
# leisewitz-julius-von-tarent 16
# leisewitz-julius-von-tarent 25
# leisewitz-julius-von-tarent 31
#
# ---------------
# Processing schnitzler-professor-bernhardi
# schnitzler-professor-bernhardi 45
# schnitzler-professor-bernhardi 75
# schnitzler-professor-bernhardi 108
# schnitzler-professor-bernhardi 140
# schnitzler-professor-bernhardi 153
#
# ---------------
# Processing eichendorff-der-letzte-held-von-marienburg
# eichendorff-der-letzte-held-von-marienburg 97
# eichendorff-der-letzte-held-von-marienburg 230
# eichendorff-der-letzte-held-von-marienburg 284
# eichendorff-der-letzte-held-von-marienburg 344
# eichendorff-der-letzte-held-von-marienburg 402
#
# ---------------
# Processing goethe-faust-der-tragoedie-zweiter-teil
# goethe-faust-der-tragoedie-zweiter-teil 1305
# goethe-faust-der-tragoedie-zweiter-teil 1678
# goethe-faust-der-tragoedie-zweiter-teil 1778
# goethe-faust-der-tragoedie-zweiter-teil 1922
# goethe-faust-der-tragoedie-zweiter-teil 2040
#
# ---------------
# Processing schiller-die-verschwoerung-des-fiesco-zu-genua
# schiller-die-verschwoerung-des-fiesco-zu-genua 40
# schiller-die-verschwoerung-des-fiesco-zu-genua 65
# schiller-die-verschwoerung-des-fiesco-zu-genua 78
# schiller-die-verschwoerung-des-fiesco-zu-genua 119
# schiller-die-verschwoerung-des-fiesco-zu-genua 150
#
# ---------------
# Processing sudermann-der-bettler-von-syrakus
# sudermann-der-bettler-von-syrakus 23
# sudermann-der-bettler-von-syrakus 188
# sudermann-der-bettler-von-syrakus 216
# sudermann-der-bettler-von-syrakus 370
# sudermann-der-bettler-von-syrakus 387
#
# ---------------
# Processing hartleben-rosenmontag
# hartleben-rosenmontag 104
# hartleben-rosenmontag 127
# hartleben-rosenmontag 132
# hartleben-rosenmontag 136
# hartleben-rosenmontag 142
#
# ---------------
# Processing bleibtreu-weltgericht
# bleibtreu-weltgericht 136
# bleibtreu-weltgericht 153
# bleibtreu-weltgericht 183
# bleibtreu-weltgericht 284
# bleibtreu-weltgericht 609
#
# ---------------
# Processing klingemann-faust
# klingemann-faust 11
# klingemann-faust 12
# klingemann-faust 34
# klingemann-faust 35
# klingemann-faust 55
#
# ---------------
# Processing quistorp-der-hypochondrist
# quistorp-der-hypochondrist 6
# quistorp-der-hypochondrist 10
# quistorp-der-hypochondrist 36
# quistorp-der-hypochondrist 38
# quistorp-der-hypochondrist 38
#
# ---------------
# Processing panizza-das-liebeskonzil
# panizza-das-liebeskonzil 126
# panizza-das-liebeskonzil 262
# panizza-das-liebeskonzil 267
# panizza-das-liebeskonzil 269
# panizza-das-liebeskonzil 270
#
# ---------------
# Processing voss-faust
# voss-faust 42
# voss-faust 113
# voss-faust 128
# voss-faust 155
# voss-faust 217
#
# ---------------
# Processing koerner-zriny
# koerner-zriny 33
# koerner-zriny 58
# koerner-zriny 74
# koerner-zriny 80
# koerner-zriny 84
#
# ---------------
# Processing hebbel-gyges-und-sein-ring
# hebbel-gyges-und-sein-ring 28
# hebbel-gyges-und-sein-ring 33
# hebbel-gyges-und-sein-ring 38
# hebbel-gyges-und-sein-ring 38
# hebbel-gyges-und-sein-ring 42
#
# ---------------
# Processing gryphius-leo-armenius-oder-fuersten-mord
# gryphius-leo-armenius-oder-fuersten-mord 19
# gryphius-leo-armenius-oder-fuersten-mord 102
# gryphius-leo-armenius-oder-fuersten-mord 113
# gryphius-leo-armenius-oder-fuersten-mord 157
# gryphius-leo-armenius-oder-fuersten-mord 181
#
# ---------------
# Processing seume-miltiades
# seume-miltiades 6
# seume-miltiades 15
# seume-miltiades 25
# seume-miltiades 39
# seume-miltiades 64
#
# ---------------
# Processing braun-von-braunthal-faust
# braun-von-braunthal-faust 73
# braun-von-braunthal-faust 110
# braun-von-braunthal-faust 139
# braun-von-braunthal-faust 154
# braun-von-braunthal-faust 162
#
# ---------------
# Processing platen-der-romantische-oedipus
# platen-der-romantische-oedipus 6
# platen-der-romantische-oedipus 42
# platen-der-romantische-oedipus 87
# platen-der-romantische-oedipus 102
# platen-der-romantische-oedipus 107
#
# ---------------
# Processing hebbel-der-diamant
# hebbel-der-diamant 9
# hebbel-der-diamant 18
# hebbel-der-diamant 30
# hebbel-der-diamant 41
# hebbel-der-diamant 83
#
# ---------------
# Processing laube-struensee
# laube-struensee 32
# laube-struensee 35
# laube-struensee 35
# laube-struensee 36
# laube-struensee 41
#
# ---------------
# Processing kotzebue-die-spanier-in-peru
# kotzebue-die-spanier-in-peru 45
# kotzebue-die-spanier-in-peru 99
# kotzebue-die-spanier-in-peru 194
# kotzebue-die-spanier-in-peru 202
# kotzebue-die-spanier-in-peru 231
#
# ---------------
# Processing grillparzer-ein-bruderzwist-in-habsburg
# grillparzer-ein-bruderzwist-in-habsburg 34
# grillparzer-ein-bruderzwist-in-habsburg 152
# grillparzer-ein-bruderzwist-in-habsburg 192
# grillparzer-ein-bruderzwist-in-habsburg 229
# grillparzer-ein-bruderzwist-in-habsburg 269
#
# ---------------
# Processing sturz-julie
# sturz-julie 9
# sturz-julie 14
# sturz-julie 16
# sturz-julie 21
# sturz-julie 25
#
# ---------------
# Processing grabbe-herzog-theodor-von-gothland
# grabbe-herzog-theodor-von-gothland 59
# grabbe-herzog-theodor-von-gothland 165
# grabbe-herzog-theodor-von-gothland 390
# grabbe-herzog-theodor-von-gothland 538
# grabbe-herzog-theodor-von-gothland 622
#
# ---------------
# Processing lassalle-franz-von-sickingen
# lassalle-franz-von-sickingen 9
# lassalle-franz-von-sickingen 26
# lassalle-franz-von-sickingen 75
# lassalle-franz-von-sickingen 211
# lassalle-franz-von-sickingen 265
#
# ---------------
# Processing brawe-brutus
# brawe-brutus 4
# brawe-brutus 6
# brawe-brutus 6
# brawe-brutus 10
# brawe-brutus 13
#
# ---------------
# Processing lenz-der-neue-menoza
# lenz-der-neue-menoza 9
# lenz-der-neue-menoza 19
# lenz-der-neue-menoza 53
# lenz-der-neue-menoza 91
# lenz-der-neue-menoza 95
#
# ---------------
# Processing gottsched-der-sterbende-cato
# gottsched-der-sterbende-cato 8
# gottsched-der-sterbende-cato 15
# gottsched-der-sterbende-cato 19
# gottsched-der-sterbende-cato 24
# gottsched-der-sterbende-cato 26
#
# ---------------
# Processing hofmannsthal-der-unbestechliche
# hofmannsthal-der-unbestechliche 29
# hofmannsthal-der-unbestechliche 37
# hofmannsthal-der-unbestechliche 40
# hofmannsthal-der-unbestechliche 42
# hofmannsthal-der-unbestechliche 57
#
# ---------------
# Processing grillparzer-koenig-ottokars-glueck-und-ende
# grillparzer-koenig-ottokars-glueck-und-ende 253
# grillparzer-koenig-ottokars-glueck-und-ende 339
# grillparzer-koenig-ottokars-glueck-und-ende 501
# grillparzer-koenig-ottokars-glueck-und-ende 561
# grillparzer-koenig-ottokars-glueck-und-ende 754
#
# ---------------
# Processing braun-mutter-maria
# braun-mutter-maria 15
# braun-mutter-maria 220
# braun-mutter-maria 727
# braun-mutter-maria 1939
# braun-mutter-maria 2044
#
# ---------------
# Processing lessing-minna-von-barnhelm
# lessing-minna-von-barnhelm 8
# lessing-minna-von-barnhelm 16
# lessing-minna-von-barnhelm 20
# lessing-minna-von-barnhelm 23
# lessing-minna-von-barnhelm 41
#
# ---------------
# Processing dehmel-michel-michael
# dehmel-michel-michael 21
# dehmel-michel-michael 197
# dehmel-michel-michael 290
# dehmel-michel-michael 431
# dehmel-michel-michael 432
#
# ---------------
# Processing krueger-die-candidaten
# krueger-die-candidaten 6
# krueger-die-candidaten 11
# krueger-die-candidaten 17
# krueger-die-candidaten 22
# krueger-die-candidaten 37
#
# ---------------
# Processing schiller-maria-stuart
# schiller-maria-stuart 9
# schiller-maria-stuart 33
# schiller-maria-stuart 39
# schiller-maria-stuart 58
# schiller-maria-stuart 73
#
# ---------------
# Processing lenz-die-freunde-machen-den-philosophen
# lenz-die-freunde-machen-den-philosophen 9
# lenz-die-freunde-machen-den-philosophen 18
# lenz-die-freunde-machen-den-philosophen 62
# lenz-die-freunde-machen-den-philosophen 64
# lenz-die-freunde-machen-den-philosophen 65
#
# ---------------
# Processing schiller-kabale-und-liebe
# schiller-kabale-und-liebe 11
# schiller-kabale-und-liebe 28
# schiller-kabale-und-liebe 31
# schiller-kabale-und-liebe 45
# schiller-kabale-und-liebe 46
#
# ---------------
# Processing gryphius-horribilicribrifax-teutsch
# gryphius-horribilicribrifax-teutsch 8
# gryphius-horribilicribrifax-teutsch 27
# gryphius-horribilicribrifax-teutsch 34
# gryphius-horribilicribrifax-teutsch 43
# gryphius-horribilicribrifax-teutsch 55
#
# ---------------
# Processing heiseler-die-kinder-godunofs
# heiseler-die-kinder-godunofs 105
# heiseler-die-kinder-godunofs 156
# heiseler-die-kinder-godunofs 167
# heiseler-die-kinder-godunofs 203
# heiseler-die-kinder-godunofs 205
#
# ---------------
# Processing hebbel-genoveva
# hebbel-genoveva 8
# hebbel-genoveva 31
# hebbel-genoveva 69
# hebbel-genoveva 75
# hebbel-genoveva 78
#
# ---------------
# Processing neuber-das-schaeferfest
# neuber-das-schaeferfest 11
# neuber-das-schaeferfest 27
# neuber-das-schaeferfest 34
# neuber-das-schaeferfest 45
# neuber-das-schaeferfest 81
#
# ---------------
# Processing grillparzer-ein-treuer-diener-seines-herrn
# grillparzer-ein-treuer-diener-seines-herrn 120
# grillparzer-ein-treuer-diener-seines-herrn 180
# grillparzer-ein-treuer-diener-seines-herrn 210
# grillparzer-ein-treuer-diener-seines-herrn 253
# grillparzer-ein-treuer-diener-seines-herrn 281
#
# ---------------
# Processing schiller-die-jungfrau-von-orleans
# schiller-die-jungfrau-von-orleans 45
# schiller-die-jungfrau-von-orleans 84
# schiller-die-jungfrau-von-orleans 113
# schiller-die-jungfrau-von-orleans 153
# schiller-die-jungfrau-von-orleans 183
#
# ---------------
# Processing gryphius-carolus-stuardus
# gryphius-carolus-stuardus 4
# gryphius-carolus-stuardus 11
# gryphius-carolus-stuardus 23
# gryphius-carolus-stuardus 73
# gryphius-carolus-stuardus 167
#
# ---------------
# Processing ludwig-der-erbfoerster
# ludwig-der-erbfoerster 35
# ludwig-der-erbfoerster 55
# ludwig-der-erbfoerster 71
# ludwig-der-erbfoerster 71
# ludwig-der-erbfoerster 76
#
# ---------------
# Processing gottschedin-die-pietisterey-im-fischbein-rocke
# gottschedin-die-pietisterey-im-fischbein-rocke 9
# gottschedin-die-pietisterey-im-fischbein-rocke 14
# gottschedin-die-pietisterey-im-fischbein-rocke 22
# gottschedin-die-pietisterey-im-fischbein-rocke 39
# gottschedin-die-pietisterey-im-fischbein-rocke 62
#
# ---------------
# Processing lessing-emilia-galotti
# lessing-emilia-galotti 4
# lessing-emilia-galotti 17
# lessing-emilia-galotti 23
# lessing-emilia-galotti 29
# lessing-emilia-galotti 31
#
# ---------------
# Processing gryphius-cardenio-und-celinde
# gryphius-cardenio-und-celinde 6
# gryphius-cardenio-und-celinde 12
# gryphius-cardenio-und-celinde 22
# gryphius-cardenio-und-celinde 74
# gryphius-cardenio-und-celinde 80
#
# ---------------
# Processing scheerbart-es-lebe-europa
# scheerbart-es-lebe-europa 10
# scheerbart-es-lebe-europa 12
# scheerbart-es-lebe-europa 21
# scheerbart-es-lebe-europa 21
# scheerbart-es-lebe-europa 24
#
# ---------------
# Processing holz-sonnenfinsternis
# holz-sonnenfinsternis 6
# holz-sonnenfinsternis 13
# holz-sonnenfinsternis 17
# holz-sonnenfinsternis 17
# holz-sonnenfinsternis 18
#
# ---------------
# Processing hebbel-agnes-bernauer
# hebbel-agnes-bernauer 55
# hebbel-agnes-bernauer 58
# hebbel-agnes-bernauer 97
# hebbel-agnes-bernauer 120
# hebbel-agnes-bernauer 172
#
# ---------------
# Processing lenz-der-hofmeister
# lenz-der-hofmeister 11
# lenz-der-hofmeister 33
# lenz-der-hofmeister 39
# lenz-der-hofmeister 55
# lenz-der-hofmeister 69
#
# ---------------
# Processing gutzkow-richard-savage
# gutzkow-richard-savage 14
# gutzkow-richard-savage 31
# gutzkow-richard-savage 37
# gutzkow-richard-savage 116
# gutzkow-richard-savage 126
#
# ---------------
# Processing kraus-die-letzten-tage-der-menschheit
# kraus-die-letzten-tage-der-menschheit 3243
# kraus-die-letzten-tage-der-menschheit 4130
# kraus-die-letzten-tage-der-menschheit 5066
# kraus-die-letzten-tage-der-menschheit 5684
# kraus-die-letzten-tage-der-menschheit 10910
#
# ---------------
# Processing hebbel-kriemhilds-rache
# hebbel-kriemhilds-rache 16
# hebbel-kriemhilds-rache 88
# hebbel-kriemhilds-rache 96
# hebbel-kriemhilds-rache 118
# hebbel-kriemhilds-rache 137
#
# ---------------
# Processing kotzebue-pagenstreiche
# kotzebue-pagenstreiche 71
# kotzebue-pagenstreiche 83
# kotzebue-pagenstreiche 95
# kotzebue-pagenstreiche 112
# kotzebue-pagenstreiche 125
#
# ---------------
# Processing grabbe-kaiser-friedrich-barbarossa
# grabbe-kaiser-friedrich-barbarossa 267
# grabbe-kaiser-friedrich-barbarossa 649
# grabbe-kaiser-friedrich-barbarossa 703
# grabbe-kaiser-friedrich-barbarossa 897
# grabbe-kaiser-friedrich-barbarossa 975
#
# ---------------
# Processing cronegk-codrus
# cronegk-codrus 9
# cronegk-codrus 11
# cronegk-codrus 17
# cronegk-codrus 28
# cronegk-codrus 32
#
# ---------------
# Processing grillparzer-die-ahnfrau
# grillparzer-die-ahnfrau 10
# grillparzer-die-ahnfrau 19
# grillparzer-die-ahnfrau 21
# grillparzer-die-ahnfrau 29
# grillparzer-die-ahnfrau 41
#
# ---------------
# Processing immermann-das-gericht-von-st-petersburg
# immermann-das-gericht-von-st-petersburg 43
# immermann-das-gericht-von-st-petersburg 52
# immermann-das-gericht-von-st-petersburg 58
# immermann-das-gericht-von-st-petersburg 160
# immermann-das-gericht-von-st-petersburg 177
#
# ---------------
# Processing panizza-nero
# panizza-nero 51
# panizza-nero 142
# panizza-nero 207
# panizza-nero 226
# panizza-nero 286
#
# ---------------
# Processing wildgans-armut
# wildgans-armut 6
# wildgans-armut 15
# wildgans-armut 18
# wildgans-armut 21
# wildgans-armut 38
#
# ---------------
# Processing lessing-der-freigeist
# lessing-der-freigeist 4
# lessing-der-freigeist 13
# lessing-der-freigeist 18
# lessing-der-freigeist 22
# lessing-der-freigeist 33
#
# ---------------
# Processing essig-ueberteufel
# essig-ueberteufel 21
# essig-ueberteufel 36
# essig-ueberteufel 44
# essig-ueberteufel 137
# essig-ueberteufel 165
#
# ---------------
# Processing wilbrandt-gracchus-der-volkstribun
# wilbrandt-gracchus-der-volkstribun 63
# wilbrandt-gracchus-der-volkstribun 90
# wilbrandt-gracchus-der-volkstribun 119
# wilbrandt-gracchus-der-volkstribun 144
# wilbrandt-gracchus-der-volkstribun 166
#
# ---------------
# Processing goethe-egmont
# goethe-egmont 14
# goethe-egmont 152
# goethe-egmont 154
# goethe-egmont 167
# goethe-egmont 174
#
# ---------------
# Processing hauptmann-florian-geyer
# hauptmann-florian-geyer 465
# hauptmann-florian-geyer 806
# hauptmann-florian-geyer 882
# hauptmann-florian-geyer 1022
# hauptmann-florian-geyer 1182
#
# ---------------
# Processing heyse-don-juans-ende
# heyse-don-juans-ende 17
# heyse-don-juans-ende 31
# heyse-don-juans-ende 32
# heyse-don-juans-ende 38
# heyse-don-juans-ende 59
#
# ---------------
# Processing grillparzer-die-juedin-von-toledo
# grillparzer-die-juedin-von-toledo 28
# grillparzer-die-juedin-von-toledo 44
# grillparzer-die-juedin-von-toledo 62
# grillparzer-die-juedin-von-toledo 73
# grillparzer-die-juedin-von-toledo 79
#
# ---------------
# Processing brachvogel-narziss
# brachvogel-narziss 62
# brachvogel-narziss 69
# brachvogel-narziss 173
# brachvogel-narziss 194
# brachvogel-narziss 262
#
# ---------------
# Processing klinger-die-zwillinge
# klinger-die-zwillinge 6
# klinger-die-zwillinge 18
# klinger-die-zwillinge 18
# klinger-die-zwillinge 26
# klinger-die-zwillinge 26
#
# ---------------
# Processing gutzkow-zopf-und-schwert
# gutzkow-zopf-und-schwert 18
# gutzkow-zopf-und-schwert 43
# gutzkow-zopf-und-schwert 74
# gutzkow-zopf-und-schwert 98
# gutzkow-zopf-und-schwert 119
#
# ---------------
# Processing scheerbart-okurirasuna
# scheerbart-okurirasuna 28
# scheerbart-okurirasuna 34
# scheerbart-okurirasuna 34
# scheerbart-okurirasuna 43
# scheerbart-okurirasuna 52
#
# ---------------
# Processing grillparzer-libussa
# grillparzer-libussa 52
# grillparzer-libussa 282
# grillparzer-libussa 289
# grillparzer-libussa 295
# grillparzer-libussa 299
#
# ---------------
# Processing schlegel-der-triumph-der-guten-frauen
# schlegel-der-triumph-der-guten-frauen 9
# schlegel-der-triumph-der-guten-frauen 12
# schlegel-der-triumph-der-guten-frauen 13
# schlegel-der-triumph-der-guten-frauen 13
# schlegel-der-triumph-der-guten-frauen 16
#
# ---------------
# Processing essig-der-frauenmut
# essig-der-frauenmut 21
# essig-der-frauenmut 28
# essig-der-frauenmut 124
# essig-der-frauenmut 131
# essig-der-frauenmut 346
#
# ---------------
# Processing grillparzer-sappho
# grillparzer-sappho 14
# grillparzer-sappho 22
# grillparzer-sappho 23
# grillparzer-sappho 29
# grillparzer-sappho 33
#
# ---------------
# Processing schiller-wallensteins-tod
# schiller-wallensteins-tod 14
# schiller-wallensteins-tod 22
# schiller-wallensteins-tod 62
# schiller-wallensteins-tod 82
# schiller-wallensteins-tod 137
#
# ---------------
# Processing weissenthurn-das-manuscript
# weissenthurn-das-manuscript 10
# weissenthurn-das-manuscript 34
# weissenthurn-das-manuscript 37
# weissenthurn-das-manuscript 38
# weissenthurn-das-manuscript 47
#
# ---------------
# Processing brawe-der-freigeist
# brawe-der-freigeist 3
# brawe-der-freigeist 6
# brawe-der-freigeist 7
# brawe-der-freigeist 7
# brawe-der-freigeist 8
#
# ---------------
# Processing lessing-miss-sara-sampson
# lessing-miss-sara-sampson 11
# lessing-miss-sara-sampson 19
# lessing-miss-sara-sampson 23
# lessing-miss-sara-sampson 27
# lessing-miss-sara-sampson 32
#
# ---------------
# Processing tieck-karl-von-berneck
# tieck-karl-von-berneck 57
# tieck-karl-von-berneck 92
# tieck-karl-von-berneck 99
# tieck-karl-von-berneck 114
# tieck-karl-von-berneck 117
#
# ---------------
# Processing gutzkow-das-urbild-des-tartueffe
# gutzkow-das-urbild-des-tartueffe 14
# gutzkow-das-urbild-des-tartueffe 32
# gutzkow-das-urbild-des-tartueffe 56
# gutzkow-das-urbild-des-tartueffe 68
# gutzkow-das-urbild-des-tartueffe 72
#
# ---------------
# Processing gutzkow-uriel-acosta
# gutzkow-uriel-acosta 10
# gutzkow-uriel-acosta 31
# gutzkow-uriel-acosta 42
# gutzkow-uriel-acosta 56
# gutzkow-uriel-acosta 58
#
# ---------------
# Processing schlegel-der-geschaeftige-muessiggaenger
# schlegel-der-geschaeftige-muessiggaenger 6
# schlegel-der-geschaeftige-muessiggaenger 20
# schlegel-der-geschaeftige-muessiggaenger 38
# schlegel-der-geschaeftige-muessiggaenger 40
# schlegel-der-geschaeftige-muessiggaenger 50
#
# ---------------
# Processing heiseler-peter-und-alexej
# heiseler-peter-und-alexej 36
# heiseler-peter-und-alexej 99
# heiseler-peter-und-alexej 176
# heiseler-peter-und-alexej 237
# heiseler-peter-und-alexej 237
#
# ---------------
# Processing weissenthurn-welche-ist-die-braut
# weissenthurn-welche-ist-die-braut 16
# weissenthurn-welche-ist-die-braut 44
# weissenthurn-welche-ist-die-braut 172
# weissenthurn-welche-ist-die-braut 175
# weissenthurn-welche-ist-die-braut 176
#
# ---------------
# Processing holz-ignorabimus
# holz-ignorabimus 6
# holz-ignorabimus 12
# holz-ignorabimus 23
# holz-ignorabimus 23
# holz-ignorabimus 23
#
# ---------------
# Processing grillparzer-weh-dem-der-luegt
# grillparzer-weh-dem-der-luegt 6
# grillparzer-weh-dem-der-luegt 27
# grillparzer-weh-dem-der-luegt 29
# grillparzer-weh-dem-der-luegt 69
# grillparzer-weh-dem-der-luegt 90
#
# ---------------
# Processing wildgans-dies-irae
# wildgans-dies-irae 15
# wildgans-dies-irae 20
# wildgans-dies-irae 34
# wildgans-dies-irae 35
# wildgans-dies-irae 53
#
# ---------------
# Processing laube-monaldeschi
# laube-monaldeschi 22
# laube-monaldeschi 36
# laube-monaldeschi 37
# laube-monaldeschi 40
# laube-monaldeschi 46
#
# ---------------
# Processing engel-eid-und-pflicht
# engel-eid-und-pflicht 7
# engel-eid-und-pflicht 11
# engel-eid-und-pflicht 16
# engel-eid-und-pflicht 30
# engel-eid-und-pflicht 32
#
# ---------------
# Processing schlegel-canut
# schlegel-canut 3
# schlegel-canut 6
# schlegel-canut 9
# schlegel-canut 12
# schlegel-canut 14
#
# ---------------
# Processing anonym-der-deutsche-student
# anonym-der-deutsche-student 5
# anonym-der-deutsche-student 20
# anonym-der-deutsche-student 29
# anonym-der-deutsche-student 33
# anonym-der-deutsche-student 37
#
# ---------------
# Processing platen-die-verhaengnisvolle-gabel
# platen-die-verhaengnisvolle-gabel 6
# platen-die-verhaengnisvolle-gabel 9
# platen-die-verhaengnisvolle-gabel 19
# platen-die-verhaengnisvolle-gabel 19
# platen-die-verhaengnisvolle-gabel 23
#
# ---------------
# Processing uhland-ernst-herzog-von-schwaben
# uhland-ernst-herzog-von-schwaben 28
# uhland-ernst-herzog-von-schwaben 34
# uhland-ernst-herzog-von-schwaben 46
# uhland-ernst-herzog-von-schwaben 64
# uhland-ernst-herzog-von-schwaben 147
#
# ---------------
# Processing bleibtreu-ein-faust-der-that
# bleibtreu-ein-faust-der-that 36
# bleibtreu-ein-faust-der-that 90
# bleibtreu-ein-faust-der-that 155
# bleibtreu-ein-faust-der-that 167
# bleibtreu-ein-faust-der-that 236
#
# ---------------
# Processing scheerbart-herr-kammerdiener-kneetschke
# scheerbart-herr-kammerdiener-kneetschke 15
# scheerbart-herr-kammerdiener-kneetschke 21
# scheerbart-herr-kammerdiener-kneetschke 26
# scheerbart-herr-kammerdiener-kneetschke 33
# scheerbart-herr-kammerdiener-kneetschke 33
#
# ---------------
# Processing kleist-die-familie-schroffenstein
# kleist-die-familie-schroffenstein 64
# kleist-die-familie-schroffenstein 76
# kleist-die-familie-schroffenstein 94
# kleist-die-familie-schroffenstein 111
# kleist-die-familie-schroffenstein 181
#
# ---------------

# %%
cumulative_G_list_ger['grillparzer-des-meeres-und-der-liebe-wellen']['acts_1-2'].edges
ger_soups['grillparzer-des-meeres-und-der-liebe-wellen'].body.find_all('div', {'type': 'act'})[0]
# Out:
# <div type="act">
# <head>Erster Aufzug</head>
# <stage>Vorhof im Tempel der Aphrodite zu Sestos. Den Mittelgrund bilden Säulen mit weiten
#           Zwischenräumen, das Peristyl bezeichnend. Im Hintergrunde der Tempel, zu dem mehrere
#           Stufen emporführen. Nach vorne, rechts die Statue Amors, links Hymenäus Bildsäule. Früher
#           Morgen.</stage>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>ein Körbchen mit Blumen im Arme haltend, tritt aus dem Tempel und steigt die Stufen
#             herab.</stage>
# <lg>
# <l>Nun, so weit wärs getan. Geschmückt der Tempel,</l>
# <l>Mit Myrt und Rosen ist er rings bestreut</l>
# <l>Und harret auf das kommende, das Fest.</l>
# </lg>
# <lg>
# <l>Und ich bin dieses Festes Gegenstand.</l>
# <l>Mir wird vergönnt, die unbemerkten Tage,</l>
# <l>Die fernhin rollen ohne Richt und Ziel,</l>
# <l>Dem Dienst der hohen Himmlischen zu weihn;</l>
# <l>Die einzelnen, die Wiesenblümchen gleich,</l>
# <l>Der Fuß des Wanderers zertritt und knickt,</l>
# <l>Zum Kranz gewunden um der Göttin Haupt,</l>
# <l>Zu weihen und verklären. Sie und mich.</l>
# </lg>
# <lg>
# <l>Wie bin ich glücklich, daß nun heut der Tag,</l>
# <l>Und daß der Tag so schön, so still, so lieblich.</l>
# <l>Kein Wölkchen trübt das blaue Firmament,</l>
# <l>Und Phöbus blickt, dem hellen Meer entstiegen,</l>
# <l>Schon über jene Zinnen segnend her.</l>
# <l>Schaust du mich schon als eine von den Euren?</l>
# <l>Ward es dir kund, daß jene muntre Hero,</l>
# <l>Die du wohl spielen sahst an Tempels Stufen,</l>
# <l>Daß sie, ergreifend ihrer Ahnen Recht,</l>
# <l>Die Priester gaben von Urväterzeit</l>
# <l>Dem hehren Heiligtum – daß sies ergreifend,</l>
# <l>Das schöne Vorrecht, Priesterin nun selbst,</l>
# <l>Und heute, heut; an diesem, diesem Tage.</l>
# <l>Auf jenen Stufen wird das Volk sie sehn,</l>
# <l>Den Himmlischen der Opfer Gaben spendend.</l>
# <l>Von jeder Lippe ringt sich Jubel los,</l>
# <l>Und in dem Glanz, der Göttin dargebracht,</l>
# <l>Strahlt auf der Priestrin Haupt –</l>
# <l><pb n="11"/> Allein, wie nur?</l>
# <l>Beginn ich mit Versäumen meinen Dienst?</l>
# <l>Hier sind noch Kränze, Blumen hab ich noch,</l>
# <l>Und jene Bilder stehen ungeschmückt?</l>
# </lg>
# <lg>
# <l>Hier, Hymenäus, der die Menschen bindet,</l>
# <l>Nimm diesen Kranz von einer, die gern frei.</l>
# <l>Die Seelen tauschest du? Ei, gute Götter,</l>
# <l>Ich will die meine nur für mich behalten,</l>
# <l>Wer weiß, ob eine andre mir so nütz?</l>
# </lg>
# <lg>
# <l>Dir, Amor, sei der zweite meiner Kränze.</l>
# <l>Bist du der Göttin Sohn und ich ihr Kind,</l>
# <l>Sind wir verwandt; und redliche Geschwister</l>
# <l>Beschädigen sich nicht und halten Ruh.</l>
# <l>So seis mit uns, und ehren will ich dich,</l>
# <l>Wie man verehrt, was man auch nicht erkennt.</l>
# </lg>
# <lg>
# <l>Nun noch die Blumen auf den Estrich. – Doch</l>
# <l>Wie liegt nur das Geräte rings am Boden?</l>
# <l>Der Sprengkrug und der Wedel, Bast und Binden.</l>
# <l>Saumselge Dienerinnen dieses Hauses,</l>
# <l>Euch stand es zu. Übt so ihr eure Pflicht?</l>
# <l>Lieg immer denn und gib ein kundbar Zeugnis –</l>
# <l>Und doch, es martert mein erglühend Auge.</l>
# <l>Fort, Niedriges, und laß mich dich nicht schaun.</l>
# </lg>
# <stage>Sich mit Zurechtstellen beschäftigend.</stage>
# <lg>
# <l>Dort kommt der Schwarm, von lautem Spiel erhitzt,</l>
# <l>Nunmehr zu tun, was ohne sie vollendet.</l>
# </lg>
# <stage>Janthe und mehrere Dienerinnen kommen.</stage>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <l>Ei, schöne Hero, schon so früh beschäftigt?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>So früh, weils andre nicht, wenn noch so spät.</l>
# <stage>Die Dienerinnen stellen das übrige zurecht.</stage>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Ei seht, sie tadelt <emph>uns</emph>, weil wir die Kanne,</l>
# <l>Das wenige Gerät nicht weggeschafft.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Viel oder wenig, du hasts nicht getan.</l>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Wir waren früh am Werk und sprengten, fegten.</l>
# <l>Da kam die Lust, im Grünen uns zu jagen.</l>
# <pb n="12"/>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Drauf gingt ihr hin und – Nun, beim hohen Himmel!</l>
# <l>Als du den leichten Fuß erhobst und senktest,</l>
# <l>Kam dir der Vorhof deiner Göttin nicht,</l>
# <l>Dein unvollendet Werk dir nicht vors Auge?</l>
# <l>Genug, ich faß euch nicht, wir wollen schweigen.</l>
# </lg>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Weil du so grämlich bist und einsam schmollst,</l>
# <l>Beneidest du dem Frohen jede Lust.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Ich bin nicht grämlich, froher leicht als ihr,</l>
# <l>Und oft hab ich zur Abendzeit beklagt,</l>
# <l>Wo Spiel vergönnt, daß ihr des Spielens müde,</l>
# <l>Doch nehm ich nicht dem Ernste seine Lust,</l>
# <l>Indem ich mit des Scherzes Lust sie menge.</l>
# </lg>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Verzeih, wir sind gemeines, niedres Volk.</l>
# <l>Du freilich, aus der Priester Stamm entsprossen –</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Du sagst es.</l>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <l>Und zu Höherem bestimmt.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Mit Stolz entgegn ich: ja.</l>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Ganz andre Freuden,</l>
# <l>Erhabnere Genüsse sind für dich.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Du weißt, ich kann nicht spotten; spotte nur!</l>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Und doch, gingst du mit uns, und sahst die beiden,</l>
# <l>Die fremden Jünglinge am Gittertor –</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Nun schweig!</l>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE.</speaker>
# <lg>
# <l>Was gilts? du blinzeltest wohl selber</l>
# <l>Ein wenig durch die Stäbe.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Schweige, sag ich.</l>
# <l>Ich habe deiner Torheit Raum gegeben,</l>
# <l>Leichtfertigem verschließt sich dieses Ohr.</l>
# <l>Sprich nicht und reg dich nicht! denn bei den Göttern!</l>
# <l>Dem Priester, meinem Oheim sag ichs an,</l>
# <l>Und er bestraft dich, wie dus wohl verdienst.</l>
# <l>Ich bin mir gram, daß mich der Zorn bemeistert,</l>
# <l>Und doch kann ich nicht anders, hör ich dies.</l>
# <l>Du sollst nicht reden, sag ich, nicht ein Wort!</l>
# </lg>
# <stage>Der Priester, von dem Tempelhüter begleitet, ist von der rechten Seite her
#             aufgetreten.</stage>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>ihm entgegen.</stage>
# <lg>
# <l>O wohl mir, daß du kömmst, mein edler Ohm.</l>
# <l>Dein Kind war im Begriff zu zürnen, heut,</l>
# <l><pb n="13"/> Am Morgen dieses feierlichen Tags,</l>
# <l>Der sie auf immer – O verzeih, mein Ohm!</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Was aber war der heißen Regung Grund?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Die argen Worte dieser Leichtgesinnten;</l>
# <l>Der frevle Hohn, der, was er selbst nicht achtet,</l>
# <l>So gern als unwert aller Achtung malte.</l>
# <l>O, daß die Weisheit halb so eifrig wäre</l>
# <l>Nach Schülern und Bekehrten, als der Spott!</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Und welche wars, die vor den andern kühn,</l>
# <l>Die Sitte unsers Hauses so verletzt?</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>nach einer Pause.</stage>
# <lg>
# <l>Genau besehn, will ich sie dir nicht nennen,</l>
# <l>Ob ihr die Rüge gleich gar wohl verdient.</l>
# <l>Schilt sie nur alle, Herr, und heiß sie gehn,</l>
# <l>Die Schuldge nimmt sich selbst wohl ihren Teil.</l>
# </lg>
# <stage>Zum Tempelhüter.</stage>
# <lg>
# <l>Du aber sieh zum äußern Gittertor,</l>
# <l>Damit nicht Fremde –</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Hätte denn –?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Ich bitte!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>So geh! – Und ihr! und meidet zu begegnen</l>
# <l>Dem Zorne, der sein Recht und seine Mittel kennt.</l>
# </lg>
# <stage>Der Tempelhüter nach der linken, die Mädchen nach der rechten Seite ab.</stage>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Nun ist mir leicht! Ich könnte sie bedauern,</l>
# <l>Wenn ihre Torheit an sich selber zehrte,</l>
# <l>Nicht um Genossen würb und Billigung.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>So sehr mich freut, daß du den Schwarm vermeidest</l>
# <l>Und aus der Menge nicht die Freundin wählst,</l>
# <l>So sehr befremdet mich, ja, ich beklag es,</l>
# <l>Daß dich zu keiner unter deinesgleichen</l>
# <l>Des Herzens Zug, ein still Bedürfnis führte.</l>
# <l>Ein einsam Leben harrt der Priesterin,</l>
# <l>Zu zweien trägt und wirkt sichs noch so leicht.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Ich kann nicht finden, daß Gesellschaft fördert;</l>
# <l>Was einem obliegt, muß man selber tun.</l>
# <l>Dann, nennst du einsam einer Priestrin Leben?</l>
# <l>Wann war es einsam hier im Tempel je?</l>
# <l>Vom frühen Morgen drängt die laute Menge,</l>
# <l><pb n="14"/> Aus Ost und Westen strömt herbei das Volk.</l>
# <l>Von Weihgeschenken und von Opfergaben,</l>
# <l>Von Festeszügen, fremden Beterscharen</l>
# <l>War nimmer dieses Hauses Schwelle leer.</l>
# <l>Dann fehlts ja nicht an mancherlei zu tun:</l>
# <l>Der Wasserkrug, der Opferherd, die Kränze,</l>
# <l>Und Säul und Sockel, Estrich und Altar</l>
# <l>Zu reinigen, zu schmücken, zu bewahren.</l>
# <l>Wo bliebe da zum Schwätzen wohl die Zeit,</l>
# <l>Zum Kosen mit der Freundin, wie du meinst.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Du hast mich nicht gefaßt.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Wohl denn, es sei!</l>
# <l>Was man nicht faßt, erregt auch kein Verlangen.</l>
# <l>Laß mich so, wie ich bin, ich bin es gern.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Doch kommt die Zeit und ändert Wunsch und Neigung.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Man klagt ja täglich, daß der Unverständge</l>
# <l>Beharrt und bleibt, man tadl ihn wie man will;</l>
# <l>Weshalb nun den Verständgen unverständger</l>
# <l>Und unbeständger glauben als den Tor?</l>
# <l>Ich weiß ja, was ich will und was wir wählten,</l>
# <l>Wenn wählen heißen kann, wo keine Wahl.</l>
# <l>Vielmehr ein glücklich Ungefähr hat mich,</l>
# <l>Nur halb bewußt, an diesen Ort gebracht,</l>
# <l>Wo – wie der Mensch, der müd am Sommerabend,</l>
# <l>Vom Ufer steigt ins weiche Wellenbad,</l>
# <l>Und, von dem lauen Strome rings umfangen,</l>
# <l>In gleiche Wärme seine Glieder breitet,</l>
# <l>So daß er, prüfend, kaum vermag zu sagen:</l>
# <l>Hier fühl ich mich und hier fühl ich ein Fremdes –</l>
# <l>Mein Wesen sich hindangibt und besitzt.</l>
# <l>Aus langer Kindheit träumerischem Staunen</l>
# <l>Bin hier ich zum Bewußtsein erst erwacht;</l>
# <l>Im Tempel, an der Göttin Fußgestelle,</l>
# <l>Ward mir ein Dasein erst, ein Ziel, ein Zweck.</l>
# <l>Wer, wenn er mühsam nur das Land gewonnen,</l>
# <l>Sehnt sich ins Meer zurück, wos wüst und schwindelnd?</l>
# <l>Ja, diese Bilder, diese Säulengänge,</l>
# <l>Sie sind ein Äußeres mir nicht, ein Totes;</l>
# <l><pb n="15"/> Mein Wesen rankt sich auf an diesen Stützen,</l>
# <l>Getrennt von ihnen, wär ich tot wie sie.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Nur hüte dich, daß so beschränktes Streben</l>
# <l>Ein Billiger nicht möge selbstisch nennen!</l>
# <l>Es hält der Mensch mit Recht von seinem Wesen</l>
# <l>Jegliche Störung fern; allein sein Leben,</l>
# <l>Ablehnend alles andre, nur auf sich,</l>
# <l>Des eignen Sinns Bewahrung zu beschränken,</l>
# <l>Scheint widrig, unerlaubt, ja ungeheuer,</l>
# <l>Und doch auch wieder eng und schwach und klein.</l>
# <l>Du weißt, es war seit undenkbaren Zeiten</l>
# <l>Begnadet von den Göttern unser Stamm</l>
# <l>Mit Priesterehren, Zeichen und Orakeln,</l>
# <l>Zu sprechen liebten sie durch unsern Mund:</l>
# <l>Lockts dich nun nicht, zurück es zu gewinnen,</l>
# <l>Das schöne Vorrecht, dir zum höchsten Ruhm</l>
# <l>Und allem Volk zu segensreichem Frommen?</l>
# <l>Ich riet dir oft, in still verborgner Nacht</l>
# <l>Zu nahen unsrer Göttin Heiligtum</l>
# <l>Und dort zu lauschen auf die leisen Stimmen,</l>
# <l>Mit denen wohl das Überirdsche spricht.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Verschiednes geben Götter an Verschiedne;</l>
# <l>Mich haben sie zur Sehrin nicht bestimmt.</l>
# <l>Auch ist die Nacht, zu ruhn; der Tag, zu wirken,</l>
# <l>Ich kann mich freuen nur am Strahl des Lichts.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Vor allem sollte heut –</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Ich war ja dort,</l>
# <l>Noch eh die Sonne kam, in unserm Tempel,</l>
# <l>Und setzte mich bei meiner Göttin Thron</l>
# <l>Und sann. Doch keine Stimme kam von oben.</l>
# <l>Da griff ich zu den Blumen, die du siehst,</l>
# <l>Und wand ihr Kränze, meiner hohen Herrin,</l>
# <l>Erst ihr, dann jenen beiden Himmlischen,</l>
# <l>Und war vergnügt.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Und dachtest?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>An mein Werk.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>An andres nicht?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Was sonst?</l>
# <pb n="16"/>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>An deine Eltern.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Was nützt es auch? sie denken nicht an mich.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Sie denken dein und sehnen sich nach dir.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Ich weiß das anders, doch du glaubst es nicht.</l>
# <l>War ihnen ich doch immer eine Last,</l>
# <l>Und fort und fort ging Sturm in ihrem Hause.</l>
# <l>Mein Vater wollte, was kein andres wollte,</l>
# <l>Und drängte mich und zürnte ohne Grund.</l>
# <l>Die Mutter duldete und schwieg.</l>
# <l>Mein Bruder – Von den Menschen all, die leben,</l>
# <l>Bin ich nur einem gram, es ist mein Bruder.</l>
# <l>Als Älterer, und weil ich nur ein Weib,</l>
# <l>Ersah er mich zum Spielwerk seiner Launen.</l>
# <l>Doch hielt ich gut und grollte still und tief.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>So zürnst du deinen Eltern?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Zürnen? O!</l>
# <l>Vergaß ich sie, geschahs, um sie zu lieben.</l>
# <l>Auch ist mein Wesen umgekehrt und eben,</l>
# <l>Seit mich die Göttin nahm in ihren Schutz.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Wenn sie nun kämen?</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Ach, sie werdens nicht.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Dich heimzuholen.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Mich? Von hier? Vergebens!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Die Mutter mit dem Bräutgam an der Hand.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>zum Gehen gewendet.</stage>
# <l>Du scherzest, Herr, und ich, ich scherzte nicht.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Bleib nur! Auch ist es Scherz. Doch deine Eltern</l>
# <l>Sind hier.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Nein! Hier?</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Seit gestern abends.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>O!</l>
# <l>Und du verhehltest mirs?</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Sie wolltens selbst,</l>
# <l>Die Weihe nicht zu stören dieser Nacht,</l>
# <l>Die dir ein Morgen ist für viele Tage.</l>
# <l>Doch bist du stark, und mögen sie denn nahn.</l>
# <l>Sieh dort den Kommenden. Er wandelt, steht,</l>
# <l>Holt tiefer Atem, nähert sich.</l>
# <pb n="17"/>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Mein Vater?</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Er selber, ja.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Und ist der Mann so alt?</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Die Frau an seiner Seite –</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Mutter! Mutter!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Erbleichst du? Eilst den Lieben nicht entgegen</l>
# <l>In froher Hast?</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>O, laß mich sie betrachten!</l>
# <l>Hab ich sie doch so lange nicht gesehn!</l>
# </lg>
# <stage>Heros Eltern kommen.</stage>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Mein Kind! Hero, mein Kind!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>auf ihre Mutter zueilend.</stage>
# <l>O meine Mutter!</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <lg>
# <l>Sieh nur, wir kommen her, den weiten Weg –</l>
# <l>Mein Atem wird schon kurz! – So fern vom Hause,</l>
# <l>Als Zeugen deines götternahen Glücks.</l>
# <l>Zu schauen, wie du in der Ahnen Spur</l>
# <l>Antrittst das Recht, um das sie uns beneiden,</l>
# <l>Die andern alle ringsumher im Land;</l>
# <l>Wie um das Amt, mit dem seit manchem Jahr</l>
# <l>Bekleidet das Vertraun mich unsrer Stadt,</l>
# <l>Und das – die böse Brust! – Was wollt ich sagen?</l>
# <l>Nun, eben deshalb kamen wir hierher.</l>
# <l>Ei, guten Morgen, Bruder!</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Meine Mutter!</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <lg>
# <l>Sie auch! Auch sie! Ob kränkelnd schon und schwach,</l>
# <l>Es duldete sie nicht im leeren Hause.</l>
# <l>Teilnehmen wollte sie an deinem Glück.</l>
# <l>Der Wagen faßt wohl zwei, so kam sie mit.</l>
# <l>Erfreuten Sinns. Und wer, wenn noch so stumpf,</l>
# <l>Erfreute sich an seinem Kinde nicht,</l>
# <l>Wenn es einhergeht auf der Hoheit Spuren?</l>
# <l>Wer horchte da auf kleinlich dunkle Zweifel,</l>
# <l>Auf, was weiß ich? Nu, wie gesagt, erfreut.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Allein sie spricht nicht.</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <lg>
# <l>Nicht? Frag sie: warum?</l>
# <l>Sie spricht wohl sonst, wenns auch nicht an der Zeit,</l>
# <l>Im Haus, den langen Tag. Frag sie: Warum?</l>
# <l>Und wieder ists auch besser, spricht sie nicht.</l>
# <l><pb n="18"/> Wer Förderliches nicht vermag zu sagen,</l>
# <l>Tut klüger, schweigt er völlig. Bruder, nicht?</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>O, guter Ohm, heiß deinen Bruder schweigen,</l>
# <l>Daß meine Mutter rede.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Bruder, laß sie!</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>So sprich; allein –</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Nicht so! Nach ihrem Herzen.</l>
# <l>Wies ihr gefällt.</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER</speaker>
# <stage>halblaut.</stage>
# <l>Mein gutes Kind!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Hörst du? Sie sprach. O süßer, süßer Klang,</l>
# <l>So lange nicht gehört. O meine Mutter!</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER</speaker>
# <stage>in den Hintergrund tretend, zu einem Diener.</stage>
# <l>Komm hier!</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <lg>
# <l>Nun weint sie gar. Daß doch! – Was schaffst du,</l>
# <l>Bruder?</l>
# </lg>
# <stage>Er geht nach rückwärts, die Hand dem gleichfalls dort stehenden Tempelhüter auf die
#             Schulter legend.</stage>
# <l>Ah, du mein Ehrenmann? – Was schafft ihr da?</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Ein Ringeltauber flog in diesen Busch,</l>
# <l>Wohl gar zu Nest. Das darf nicht sein. He, Sklave,</l>
# <l>Durchforsche du das Laub und nimm es aus!</l>
# </lg>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Wie nur? Warum?</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>So wills des Tempels Übung.</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Doch jene –</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Laß sie nur!</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Sie reden.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Laß sie!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>mit ihrer Mutter im Vorgrunde rechts.</stage>
# <lg>
# <l>Nun aber, Mutter, hemme deine Tränen,</l>
# <l>Vielmehr sag deutlich, was du fühlst und denkst.</l>
# <l>Ich höre dich und folge leicht und gern;</l>
# <l>Denn nicht mehr jenes wilde Mädchen bin ich,</l>
# <l>Das du gekannt in deines Gatten Hause,</l>
# <l>Die Göttin hat das Herz mir umgewandelt,</l>
# <l>Und ruhig kann ich denken nun und schaun.</l>
# <l>Auch –</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <l>Kind!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Was ist?</l>
# <pb n="19"/>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <l>Sie sehn nach uns.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Ei, immer!</l>
# <l>Im Tempel hier hat auch die Frau ein Recht,</l>
# <l>Und die Gekränkten haben freie Sprache.</l>
# <l>Doch ängstet dich ihr Aug, wohlan, so tret ich</l>
# <l>Hin zwischen dich und sie. Kein Blick erreicht dich.</l>
# <l>Nun aber sag, ob ich dich recht erriet:</l>
# <l>Nicht gleichen Sinns mit deinem Gatten kamst du,</l>
# <l>Und wäre dir der freie Wunsch gewährt,</l>
# <l>Du führtest gar die Tochter mit dir heim.</l>
# <l>Aus ihres Glückes sturmbeschützter Ruh</l>
# <l>In deiner dunkeln Sorgen niedre Hütte?</l>
# <l>Ists also? Ist es wahr? Sprich nein, o Mutter!</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <l>Kind, ich bin alt und bin allein.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Allein?</l>
# <l>Dir ist dein Gatte ja. Zwar er –? Ein reiches Haus;</l>
# <l>Sind Dienerinnen, die dein sorglich warten.</l>
# <l>Dann – Gute Götter, so vergaß ich denn</l>
# <l>Das Beste bis zuletzt. Dir ist mein Bruder,</l>
# <l>Der bringt die Braut ins Haus und dehnt sich breit,</l>
# <l>Und gibt dir Enkel mit der Väter Namen.</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <l>Dein Bruder, Kind –</l>
# </sp>
# <sp who="#vater">
# <speaker>VATER</speaker>
# <stage>im Hintergrunde zum Sklaven.</stage>
# <l>Greif herzhaft immer zu!</l>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <l>Dein Bruder, Kind, ist nicht mehr heim bei uns!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Wie, nicht?</l>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <lg>
# <l>Nach manchem herben Leid,</l>
# <l>Den Eltern doppelt schwer, verließ er uns,</l>
# <l>Verließ die Braut, die sein in Tränen dachte,</l>
# <l>Und zog dahin mit gleichgesinnten Männern</l>
# <l>Auf kühne Wagnis in entferntes Land.</l>
# <l>Zu Schiff, zu Roß? Wer weiß? wer kann es wissen?</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>So ist er nicht mehr da? Nun doppelt gerne</l>
# <l>Kehrt ich mit dir nach Haus, seit kund mir solches.</l>
# <l>Doch ist nicht er, sind da noch hundert andre,</l>
# <l>Von gleichem Sinn und störrisch wildem Wesen.</l>
# <l>Das ehrne Band der Roheit um die Stirn,</l>
# <l>Je minder denkend, um so heftger wollend.</l>
# <l><pb n="20"/> Gewohnt zu greifen mit der starren Hand</l>
# <l>Ins stille Reich geordneter Gedanken,</l>
# <l>Wo die Entschlüsse keimen, wachsen, reifen</l>
# <l>Am milden Strahl des gottentsprungnen Lichts.</l>
# <l>Hineinzugreifen da und zu zerstören,</l>
# <l>Hier zu entwurzeln, dort zu treiben, fördern</l>
# <l>Mit blindem Sinn und ungeschlachter Hand.</l>
# <l>Und unter solchen wünschtest du dein Kind?</l>
# <l>Vielleicht wohl gar –?</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <lg>
# <l>Was soll ich dirs verhehlen?</l>
# <l>Das Weib ist glücklich nur an Gattenhand.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Das darfst du sagen, ohne zu erröten?</l>
# <l>Wie? und mußt hüten jenes Mannes Blick,</l>
# <l>Des Herren, deines Gatten? Darfst nicht reden,</l>
# <l>Mußt schweigen, flüstern, ob du gleich im Recht,</l>
# <l>Ob du die Weisre gleich, stillwaltend Beßre?</l>
# <l>Und wagst zu sprechen mir ein solches Wort?</l>
# </lg>
# </sp>
# <sp who="#vater">
# <speaker>VATER</speaker>
# <stage>im Hintergrunde.</stage>
# <l>Die Mutter flattert auf.</l>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <lg>
# <l>O wehe, weh!</l>
# <l>Sie haben mir mein frommes Kind entwendet,</l>
# <l>Ihr Herz geraubt mit selbstisch eitlen Lehren,</l>
# <l>Daß meiner nicht mehr denkend, harten Sinns,</l>
# <l>Sie achtlos hört der Nahverwandten Worte!</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>von ihr wegtretend.</stage>
# <lg>
# <l>Ich aber will mit heiterm Sinne wandeln</l>
# <l>Hier an der Göttin Altar, meiner Frau.</l>
# <l>Das Rechte tun, nicht, weil man mirs befahl,</l>
# <l>Nein, weil es recht, weil ich es so erkannt.</l>
# <l>Und niemand soll mirs rauben und entziehn.</l>
# </lg>
# <stage>Mit starker Betonung.</stage>
# <l>Wahrhaftig!</l>
# </sp>
# <sp who="#der_sklave">
# <speaker>DER SKLAVE</speaker>
# <stage>der im Hintergrunde, auf einem Schemmel stehend, den Busch durchsucht,
#             strauchelnd.</stage>
# <l>Ah!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>umschauend.</stage>
# <l>Was ist?</l>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <lg>
# <l>So siehst du nicht?</l>
# <l>Unschuldig fromme Vögel stören sie</l>
# <l><pb n="21"/> Und nehmen aus ihr Nest. So reißen sie</l>
# <l>Das Kind auch von der Mutter, Herz vom Herzen,</l>
# <l>Und haben des ihr Spiel. O, weh mir, weh!</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Du zitterst, du bist bleich.</l>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER.</speaker>
# <lg>
# <l>O, seh ich doch</l>
# <l>Mein eignes Los.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER</speaker>
# <stage>zu dem Diener, der das Nest in ein Körbchen gelegt, auf dem oben die brütende Taube
#             sichtbar ist.</stage>
# <l>Geh nur und trag es fort!</l>
# <stage>Der Diener geht.</stage>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Halt du und setz es ab, wenns jene kränkt.</l>
# <l>Gib, sag ich!</l>
# </lg>
# <stage>Sie hat dem Diener das Körbchen abgenommen.</stage>
# <lg>
# <l>Armes Tier, was zitterst du?</l>
# <l>Sieh, Mutter, es ist heil.</l>
# </lg>
# <stage>Die Taube streichelnd.</stage>
# <l>Bist du erschrocken?</l>
# <stage>Sie setzt sich auf den Stufen der Bildsäule links im Vorgrunde nieder, das Körbchen
#             in den Händen; indem sie bald durch Emporheben die Taube zum Fortfliegen anlockt, bald
#             betrachtend und untersuchend sich mit ihr beschäftigt.</stage>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER</speaker>
# <stage>zum Diener.</stage>
# <l>Was ist? Befahl ich nicht?</l>
# <stage>Der Diener weist entschuldigend auf Hero.</stage>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER</speaker>
# <stage>zu ihr tretend.</stage>
# <lg>
# <l>Bist du so neu im Dienst,</l>
# <l>Daß du nicht weißt, was Brauches hier und Sitte?</l>
# </lg>
# </sp>
# <sp who="#mutter">
# <speaker>MUTTER</speaker>
# <stage>rechts im Vorgrunde stehend.</stage>
# <l>Mein Herz vergeht. O jammervoller Anblick!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER</speaker>
# <stage>zu ihr hinübersprechend.</stage>
# <lg>
# <l>Nun also denn zu dir. Schwachmütig Weib,</l>
# <l>Was kommst du her, zu stören diese Stunde?</l>
# <l>Und staunst ob dem, was du doch längst gewußt,</l>
# <l>Der heilgen Ordnung dieses Götterhauses.</l>
# <l>Kein Vogel baut beim Tempel hier sein Nest,</l>
# <l>Nicht girren ungestraft im Hain die Tauben,</l>
# <l>Die Rebe kriecht um Ulmen nicht hinan.</l>
# <l>All, was sich paart, bleibt ferne diesem Hause,</l>
# <l>Und jene dort fügt heut sich gleichem Los.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>die Taube streichelnd.</stage>
# <l>Du armes Tier, wie streiten sie um uns!</l>
# <pb n="22"/>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Scheint dir das schwer, und zitterst du darob?</l>
# <l>Was willst du? soll sie heim? Komm hier und nimm sie!</l>
# <l>Was braucht die Göttin dein und deines Kinds?</l>
# <l>Nicht ehrt man hier die irdsche Aphrodite,</l>
# <l>Die Mensch an Menschen knüpft wie Tier an Tier,</l>
# <l>Die Himmlische, dem Meeresschaum entstiegen,</l>
# <l>Einend den Sinn, allein die Sinne nicht,</l>
# <l>Der Eintracht alles Wesens hohe Mutter,</l>
# <l>Geschlechtlos, weil sie selber das Geschlecht,</l>
# <l>Und himmlisch, weil sie stammt vom Himmel oben.</l>
# <l>Was braucht die Göttin dein und deines Kinds?</l>
# <l>Geh hin und bette sie in Niedrigkeit,</l>
# <l>In der du selbst, dir selbst zur Qual, dich abmühst.</l>
# <l>Sie sei die Magd des Knechtes, der sie freit,</l>
# <l>Statt hier auf lichter Bahn, nach eignem Ziel,</l>
# <l>Die einzge sie des dürftigen Geschlechts,</l>
# <l>Ein Selbst zu sein, ein Wesen, eine Welt.</l>
# <l>Allein du willst es, sie ist frei, hier nimm sie!</l>
# <l>Bist du die Mutter doch! Du, Hero, folge!</l>
# <l>Die Torheit ruft. Folg ihr als Mensch, als Weib!</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>aufstehend, zur Taube.</stage>
# <l>Da gilt es denn zu reden, kleines Ding!</l>
# <stage>Das Körbchen dem Diener gebend.</stage>
# <lg>
# <l>Du nimms und trag es hin und gib ihm Freiheit,</l>
# <l>Die Freiheit wie das Tier sie kennt und wünscht.</l>
# </lg>
# <stage>Diener ab.</stage>
# <lg>
# <l>Du aber, Ohm, schilt meine Mutter nicht,</l>
# <l>Denn fromm ist ihre Meinung und sie liebt mich.</l>
# <l>Uns andre laß nur schweigen, Stille, Gute!</l>
# <l>Hat er doch recht und tut nur, was ihm Pflicht.</l>
# <l>Ich soll mit dir? Bleib du bei mir! O, Mutter!</l>
# <l>Wenn dich die Deinen quälen, komm zu mir.</l>
# <l>Hier ist kein Krieg, hier schlägt man keine Wunden,</l>
# <l>Die Göttin grollet nicht, und dieser Tempel</l>
# <l>Sieht immerdar mich an mit gleichem Blick.</l>
# <l>Kennst du das Glück des stillen Selbstbesitzes?</l>
# <l>Du hast es nie gekannt; drum sei nicht neidisch!</l>
# <l>Nein, frohen Mutes folge mir zum Fest!</l>
# <l><pb n="23"/> Heut, stolz im Siegerschritt, und kommt der Morgen,</l>
# <l>Einförmig still, den Wasserkrug zur Hand,</l>
# <l>Beschäftigt, wie bisher, an den Altären;</l>
# <l>Und fort so, Tag um Tag. Willst du, so komm!</l>
# <l>Sieh nur: sonst trag ich dich, denn ich bin stark.</l>
# <l>Allein sie will. Sie lächelt. Siehst du, Ohm?</l>
# </lg>
# <stage>Halblaut.</stage>
# <lg>
# <l>Gib nur das Zeichen nun. Du aber folge,</l>
# <l>Die Zeit verrinnt, man rüstet schon das Fest.</l>
# </lg>
# <stage>Im Gehen, tändelnd.</stage>
# <lg>
# <l>Und siehst du erst den Schmuck, die reichen Kleider,</l>
# <l>Und was man all mir Herrliches bereitet,</l>
# <l>Du sollst wohl selbst –</l>
# </lg>
# <stage>Ein paar Schritte voraus und dann zurückkehrend.</stage>
# <l>Und eile mir ein wenig!</l>
# <stage>Beide nach der rechten Seite ab.</stage>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Nun, Bruder, aber rasch –</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Rasch, und warum?</l>
# <l>Was lange dauern soll, sei lang erwogen.</l>
# <l>Wüßt ich sie schwach, noch jetzt entließ ich sie.</l>
# </lg>
# </sp>
# <sp who="#vater">
# <speaker>VATER.</speaker>
# <l>Allein bedenk!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <lg>
# <l>Zugleich bedenk ich wirklich,</l>
# <l>Daß heilsam feste Nötigung der Abschluß</l>
# <l>Von jedem irdisch wankem, wirrem Tun.</l>
# <l>Du wähltest ewig unter Möglichkeiten,</l>
# <l>Wär nicht die Wirklichkeit als Grenzstein hingesetzt.</l>
# <l>Die freie Wahl ist schwacher Toren Spielzeug.</l>
# <l>Der Tüchtge sieht in jedem Soll ein Muß,</l>
# <l>Und Zwang, als erste Pflicht, ist ihm die Wahrheit.</l>
# </lg>
# <stage>Zu den Dienern gewendet.</stage>
# <l>Das Fest beginnt.</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS STIMME</speaker>
# <stage>hinter der Szene.</stage>
# <l>Hierher nur, hier!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Was ist?</l>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <lg>
# <l>Zwei Fremdlinge, des langen Harrens müde,</l>
# <l>Sie bahnen selbst durch Büsche sich den Weg.</l>
# <l>– Kehrt ihr zurück? – Dieselben sind es, Herr,</l>
# <l>Die heute morgens schon am Gittertor –</l>
# <l><pb n="24"/> Auch dort von rückwärts wächst des Volkes Drang,</l>
# <l>Das murrend nur erträgt die Zögerung.</l>
# </lg>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Weis jene dort zurück.</l>
# <stage>Der Tempelhüter nach der linken Seite ab.</stage>
# <l>Ihr andern öffnet</l>
# <stage>Zu mehreren Dienern, die nach und nach vom Hintergrunde her eingetreten
#             sind.</stage>
# <l>Die äußern Pforten nach dem Weg zur Stadt.</l>
# <stage>Zu seinem Bruder.</stage>
# <lg>
# <l>Gönn nur indes ein Wort des Danks den Göttern,</l>
# <l>Die Nachruhm dir in deinem Kind erweckt.</l>
# </lg>
# <stage>Der Alte steht an seinem Stabe gegen den Tempel geneigt.</stage>
# <lg>
# <l>Laßt ein das Volk und haltet Ordnung, hört ihr?</l>
# <l>Daß Roheit nicht die schöne Feier störe.</l>
# <l>Auch über euch wacht sorglich, eben heut;</l>
# <l>Die Lust hat ihren Tag, so wie die Sonne,</l>
# <l>Doch auch wie jene einen Abend: Reue.</l>
# </lg>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER</speaker>
# <stage>hinter der Szene.</stage>
# <l>Nein, sag ich, nein.</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS</speaker>
# <stage>ebenso.</stage>
# <l>So hört doch, lieber Herr!</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Tut eure Pflicht, du, Bruder, aber komm!</l>
# <stage>Beide nach der rechten Seite ab.</stage>
# </sp>
# <sp who="#tempelhueter">
# <speaker>DER TEMPELHÜTER</speaker>
# <stage>auftretend.</stage>
# <lg>
# <l>Hier steh ich, hier. Und wagst dus, kühner Knabe,</l>
# <l>Und setzest über mich hin deinen Fuß?</l>
# </lg>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS</speaker>
# <stage>der gleichfalls sichtbar geworden ist.</stage>
# <lg>
# <l>Nicht über euch, doch, seht ihr, neben euch.</l>
# <l>Und also bin ich hier. Leander, komm!</l>
# </lg>
# <stage>Leander tritt auf.</stage>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>O Jugendübermut! Ward euch nicht kund –?</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <lg>
# <l>Nichts ward uns kund; denn Fremde sind wir, Herr,</l>
# <l>Und kommen von Abydos naher Küste</l>
# <l>Nach Sestos her, um euer Fest zu schaun.</l>
# </lg>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>Doch lehrt man Sittsamkeit nicht auch bei euch?</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <lg>
# <l>Wohl lehrt man sie, zugleich mit andern Sprüchen,</l>
# <l>Als: sei nicht blöd! sonst kehrst du hungrig heim.</l>
# </lg>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>Ich aber –</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <lg>
# <l>Seht, indes ihr hier euch abmüht</l>
# <l>Um uns, die zwei, strömt dort das Volk in Haufen.</l>
# <pb n="25"/>
# </lg>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>Zurück da! Hört ihr wohl?</l>
# <stage>Er wendet sich nach dem Hintergrunde und ordnet das Volk, das von der linken Seite,
#             nahe den Stufen des Tempels, hereindringt.</stage>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS</speaker>
# <stage>zu Leander.</stage>
# <lg>
# <l>Was zerrst du mich?</l>
# <l>Wir sind nun einmal da. Wer wagt, gewinnt.</l>
# <l>Hier ist der beste Platz. Fest auf den Sockel</l>
# <l>Setz ich den Fuß. Laß sehn, wer mich vertreibt,</l>
# <l>Und sieh mir nur nach all der Herrlichkeit!</l>
# <l>Das Gotteshäuslein dort, das Tor, die Säulen;</l>
# <l>So was erblickst du nimmermehr daheim.</l>
# <l>Schau! einen Altar setzt man in die Mitte,</l>
# <l>Wohl um zu opfern drauf. – Doch wonach schaust du?</l>
# <l>Blickt er zu Boden nicht! Nu, bei den Göttern!</l>
# <l>Befällt er hier dich auch, der alte Trübsinn?</l>
# <l>Ich aber sage dir –</l>
# </lg>
# <stage>Das Volk hat sich nach und nach, der linken Seite entlang, geordnet, bis dahin, wo
#             die beiden Freunde stehen.</stage>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS</speaker>
# <stage>umschauend.</stage>
# <lg>
# <l>Nun, guter Freund,</l>
# <l>Ihr drängt gar scharf.</l>
# </lg>
# <stage>Zu Leander.</stage>
# <lg>
# <l>Hörst du? ich sage dir:</l>
# <l>Weißt du nicht heute abend klein und groß</l>
# <l>Mir zu erzählen, was sich hier begab,</l>
# <l>Und trinkst nicht einen großen Becher Wein</l>
# <l>Lautjubelnd drauf, sind wir geschiedne Leute.</l>
# <l>Denn all der düstre Sinn – Allein, sieh dort!</l>
# <l>Die beiden Mädchen. Schau! es sind dieselben,</l>
# <l>Die heute früh wir sahn am Gittertor.</l>
# <l>Sie blinzeln her. Gefällt dir eine? Sprich!</l>
# </lg>
# <stage>Janthe und eine zweite Dienerin haben einen tragbaren Altar gebracht und stellen
#             ihn, rechts im Vorgrunde, vor der Bildsäule Amors nieder.</stage>
# </sp>
# <sp who="#janthe">
# <speaker>JANTHE</speaker>
# <stage>während des Zurechtstellens ihrer Gefährtin zuflüsternd.</stage>
# <lg>
# <l>Dort sind sie. Rechts der Blonde, Größere.</l>
# <l>Der Braune scheint betrübt. Was fehlt ihm nur?</l>
# </lg>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <l>Absichtlich zögern sie. Hui, welch ein Blick!</l>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER</speaker>
# <stage>nach vorn kommend, zu den Mädchen.</stage>
# <l>Ei ja, und nun auch ihr! Das findet sich.</l>
# <stage>Die Mädchen gehen <pb n="26"/> zu den Jünglingen.</stage>
# <l>Ihr scheint mir rasch zu allem, was verwehrt.</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <l>Je, wies nun kommt. Wer zweifelt, der verliert.</l>
# <stage>Man hat einen zweiten Altar gebracht, der links vor Hymenäus Bildsäule hingestellt
#             wird. Ein dritter stand schon früher an den Stufen in der Mitte.</stage>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>Ihr gebt nur Raum! Der Altar soll dort hin.</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <l>Hab ich erst Raum, so teil ich gerne mit.</l>
# </sp>
# <sp who="#tempelhueter">
# <speaker>TEMPELHÜTER.</speaker>
# <l>Und seid nur sittig und vermeßt euch nichts.</l>
# <stage>Musik von Flöten beginnt.</stage>
# <l>Der Zug beginnt. Zurück! Laßt frei die Mitte!</l>
# <stage>Das Volk ordnend, das auf der linken Seite sich in Reihen stellt.</stage>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <lg>
# <l>Sie kommen, schau! Betrachte mirs mit Fleiß!</l>
# <l>Und naht die Priesterin, streif an ihr Kleid,</l>
# <l>Das soll den Trübsinn heilen, sagt man. Hörst du?</l>
# </lg>
# <stage>Unter Musik von Flöten kommt der Zug von der rechten Seite her auf die Bühne.
#             Opferknaben mit Gefäßen. Die Oberhäupter von Sestos. Tempeldienerinnen, darunter Janthe.
#             Priester. Hero mit Mantel und Kopfbinde an der Seite ihres Oheims. Ihre Eltern
#             folgen.</stage>
# <stage>Gesang.</stage>
# <lg>
# <l>Mutter der Sterblichen,</l>
# <l>Himmelbewohnerin,</l>
# <l>Neig uns ein günstiges,</l>
# <l>Schirmendes Aug!</l>
# </lg>
# <stage>Die Begleiter des Zuges stellen sich zur rechten Seite auf, den Reihen des Volkes
#             gegenüber. Der mittlere Teil der Bühne ist leer.</stage>
# </sp>
# <sp who="#die_priester">
# <speaker>DIE PRIESTER</speaker>
# <stage>indem sie sich aufstellen.</stage>
# <l>Den Göttern Ehrfurcht!</l>
# </sp>
# <sp who="#das_volk">
# <speaker>DAS VOLK</speaker>
# <stage>antwortend.</stage>
# <l>Glück mit uns!</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <lg>
# <l>Dort kommt die Priesterin. Ein schönes Weib.</l>
# <l>Komm, laß uns knien. Doch nein, vorher noch schau mir</l>
# <l>Querüber hier dem Fußgestell nach rückwärts,</l>
# <l>Wie sie die Weihen üben, was sie tun.</l>
# </lg>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>im Hintergrunde, bei dem dort angesetzten tragbaren Altare stehend. Vor ihr knien
#             zwei Opferknaben, Rauchwerk in reichen Gefäßen haltend.</stage>
# <lg>
# <l>Ein neuer Sprößling deines alten Hauses.</l>
# <l>Sei ihm geneigt, und mehr, als er verdient.</l>
# </lg>
# <stage>Sie gießt Rauchwerk in die Flamme und geht dann nach vorn, der Priester zu ihrer
#             Linken, hinter ihr die Eltern. Der Tempelhüter in einiger Entfernung.</stage>
# </sp>
# <sp who="#die_priester">
# <speaker>DIE PRIESTER.</speaker>
# <l>Den Göttern Ehrfurcht!</l>
# <pb n="27"/>
# </sp>
# <sp who="#das_volk">
# <speaker>DAS VOLK.</speaker>
# <l>Glück mit uns!</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS.</speaker>
# <l>Sie kommen näher. Nun, Leander, knie!</l>
# <stage>Sie knien. Leander hart an der Bildsäule des Hymenäus, Naukleros etwas
#             zurück.</stage>
# <stage>Auch das übrige Volk kniet.</stage>
# <stage>Hero ist zu Amors Bildsäule gekommen und gießt Rauchwerk in die Flamme des daneben
#             stehenden Altars, der Priester ihr zur Seite.</stage>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <lg>
# <l>Der du die Liebe gibst, nimm all die meine.</l>
# <l>Dich grüßend, nehm ich Abschied auch von dir.</l>
# </lg>
# <stage>Sie entfernt sich.</stage>
# </sp>
# <sp who="#die_priester">
# <speaker>DIE PRIESTER.</speaker>
# <l>Den Göttern Ehrfurcht!</l>
# </sp>
# <sp who="#das_volk">
# <speaker>DAS VOLK.</speaker>
# <l>Glück mit uns!</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO</speaker>
# <stage>an der Bildsäule des Hymenäus stehend.</stage>
# <l>Dein Bruder sendet mich –</l>
# </sp>
# <sp who="#naukleros">
# <speaker>NAUKLEROS</speaker>
# <stage>leise zu Leander.</stage>
# <l>Siehst du nicht auf?</l>
# </sp>
# <sp who="#leander">
# <speaker>LEANDER</speaker>
# <stage>der gerade vor sich hin auf den Boden gesehen hat, hebt jetzt das Haupt
#             empor.</stage>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Was ist? Du stockst.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Herr, ich vergaß die Zange.</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Du hältst sie in der Hand.</l>
# </sp>
# <sp who="#hero">
# <speaker>HERO.</speaker>
# <l>Der du die Liebe –</l>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>So hieß der erste Spruch. Laß nur! Zum Opfer!</l>
# <stage>Hero gießt Rauchwerk ins Feuer. Eine lebhaftere Flamme zuckt empor.</stage>
# </sp>
# <sp who="#priester">
# <speaker>PRIESTER.</speaker>
# <l>Zu viel! – Doch gut! – Nun noch zum Tempel! Komm!</l>
# <stage>Sie entfernen sich. In die Mitte der Bühne gekommen, sieht Hero, als nach etwas
#             Fehlendem an ihrem Schuh, über die rechte Schulter zurück. Ihr Blick trifft dabei auf
#             die beiden Jünglinge. Die Eltern kommen ihr entgegen. Die Musik ertönt von
#             neuem.</stage>
# </sp>
# <stage>Der Vorhang fällt.</stage>
# </div>

# %%
# Write csv for no epilogue no prologue section

csv_filename = 'gerdracor_cumulative2_no_pro_epi.csv'
column_names = ['title', 'title_pretty', 'genre']
metric_names = ['density', 'diameter', 'average_clustering']
most_acts = max([len(v) for v in cumulative_G_list_ger.values()]) - 1

for act in range(1, 5+1):
    for n in metric_names:
        column_names.append(f"acts_{'-'.join([str(n) for n in range(1, act+1)])}_{n}")

ger_result_dict = defaultdict(dict)
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()
    
    for name, drama_data in cumulative_G_list_ger.items():
        drama_dict = {'title': name,
                      'title_pretty': drama_data['title_pretty'],
                      'genre': drama_data['genre']
             }
        
        
        for act in range(1, 5+1):
            acts_name = f"acts_{'-'.join([str(n) for n in range(1, act+1)])}"
            if acts_name in drama_data.keys():
                drama_dict[f"{acts_name}_density"] = nx.density(drama_data[acts_name])
                drama_dict[f'{acts_name}_diameter'] = nx.diameter(get_largest_G(drama_data[acts_name], name))
                drama_dict[f'{acts_name}_average_clustering'] = nx.average_clustering(drama_data[acts_name])
            else:
                raise ValueError(f'{acts_name} not in {name}')
        ger_result_dict[name] = drama_dict
        writer.writerow(drama_dict)

# %% [markdown]
# **GERDRACOR STRUCTURES**

# %%
def div_structure(unit, indent):
    for div in unit.find_all('div', recursive=False):
        print(f"""{indent*" "}{div['type']}""")
        div_structure(div, indent+2)
for name, soup in ger_soups.items():
    if name in ['hebbel-genoveva', 'neuber-das-schaeferfest']:
        body = soup.find('body')
        div_structure(body, 2)
# Out:
#   act
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   epilogue
#     Dramatis_Personae
#     set
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   act
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#     scene
#   epilogue

# %%
ger_result_dict = defaultdict(dict)
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()
    
    for name, drama_data in cumulative_G_list_ger.items():
        drama_dict = {'title': name,
                      'title_pretty': drama_data['title_pretty'],
                      'genre': drama_data['genre']
             }
        
        for section in ['epilogue', 'prologue']:
            if drama_data[section] is not None:
                density = nx.density(drama_data[section])
                diameter = nx.diameter(get_largest_G(drama_data[section], name))
                average_clustering = nx.average_clustering(drama_data[section])
            else:
                density, diameter, average_clustering = None, None, None
                
            drama_dict[f"{section}_density"] = density
            drama_dict[f'{section}_diameter'] = diameter
            drama_dict[f'{section}_average_clustering'] = average_clustering
        
        for act in range(1, 5+1):
            acts_name = f"acts_{'-'.join([str(n) for n in range(1, act+1)])}"
            if acts_name in drama_data.keys():
                drama_dict[f"{acts_name}_density"] = nx.density(drama_data[acts_name])
                drama_dict[f'{acts_name}_diameter'] = nx.diameter(get_largest_G(drama_data[acts_name], name))
                drama_dict[f'{acts_name}_average_clustering'] = nx.average_clustering(drama_data[acts_name])
        ger_result_dict[name] = drama_dict
        writer.writerow(drama_dict)

# %% [markdown]
# **GERDRACOR CSV WRITING**

# %%
csv_filename = 'gerdracor_cumulative3.csv'
column_names = ['title', 'title_pretty', 'genre']
metric_names = ['density', 'diameter', 'average_clustering']
most_acts = max([len(v) for v in cumulative_G_list_ger.values()]) - 1

for act in range(1, 5+1):
    for n in metric_names:
        column_names.append(f"acts_{'-'.join([str(n) for n in range(1, act+1)])}_{n}")
        
for section in ['epilogue', 'prologue']:
    for n in metric_names:
        column_names.append(f"{section}_{n}")

# %%
ger_result_dict = defaultdict(dict)
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()
    
    for name, drama_data in cumulative_G_list_ger.items():
        drama_dict = {'title': name,
                      'title_pretty': drama_data['title_pretty'],
                      'genre': drama_data['genre']
             }
        
        for section in ['epilogue', 'prologue']:
            if drama_data[section] is not None:
                density = nx.density(drama_data[section])
                diameter = nx.diameter(get_largest_G(drama_data[section], name))
                average_clustering = nx.average_clustering(drama_data[section])
            else:
                density, diameter, average_clustering = None, None, None
                
            drama_dict[f"{section}_density"] = density
            drama_dict[f'{section}_diameter'] = diameter
            drama_dict[f'{section}_average_clustering'] = average_clustering
        
        for act in range(1, 5+1):
            acts_name = f"acts_{'-'.join([str(n) for n in range(1, act+1)])}"
            if acts_name in drama_data.keys():
                drama_dict[f"{acts_name}_density"] = nx.density(drama_data[acts_name])
                drama_dict[f'{acts_name}_diameter'] = nx.diameter(get_largest_G(drama_data[acts_name], name))
                drama_dict[f'{acts_name}_average_clustering'] = nx.average_clustering(drama_data[acts_name])
        ger_result_dict[name] = drama_dict
        writer.writerow(drama_dict)

# %% [markdown]
# **CROSSCHECK GERDRACOR**

# %%
metadata_df = pd.read_csv(original_gerdracor_metadata_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [187], in <cell line: 1>()
# ----> 1 metadata_df = pd.read_csv(original_gerdracor_metadata_file)
#
# NameError: name 'original_gerdracor_metadata_file' is not defined

# %%
metadata_df = metadata_df.set_index('name')

# %%
not_matching = set()
df_data = []
for name, drama_dict in cumulative_G_list_ger.items():
    row = {'name': name}
    
    G = drama_dict['whole']
    my_density = nx.density(G)
    my_diameter = nx.diameter(get_largest_G(G, name))
    my_average_clustering = nx.average_clustering(G)
    
    if round(my_density, 2) != round(metadata_df.loc[name]['density'], 2):
        row['density'] = metadata_df.loc[name]['density']
        row['my_density'] = my_density
    if round(my_diameter, 2) != round(metadata_df.loc[name]['diameter'], 2):
        row['diameter'] = metadata_df.loc[name]['diameter']
        row['my_diameter'] = my_diameter
    if round(my_average_clustering, 2) != round(metadata_df.loc[name]['averageClustering'], 2):
        row['avg_clu'] = metadata_df.loc[name]['averageClustering']
        row['my_avg_clu'] = my_average_clustering
    if len(row) > 1:
        df_data.append(row)
pd.DataFrame(df_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **GERDRACOR STATS**

# %%
ger_dracor_stats = []
for name, soup in ger_soups.items():
    
    acts = len(soup.find_all('div', {'type': 'act'})) > 0
    prologue = len(soup.find_all('div', {'type': 'prologue'})) > 0
    scenes = len(soup.find_all('div', {'type': 'scene'})) > 0
    configurations = len(soup.find_all('div', {'type': 'configuration'})) > 0
    locations = len(soup.find_all('div', {'type': 'location'})) > 0
    
    if all(elem is False for elem in [acts, scenes, configurations, locations]):
        raise ValueError(f'CONTENT HOLDER DIVS NOT ACCOUNTED FOR {name}')

    # has acts and scenes
    if acts and scenes:
        if scenes is False:
            raise ValueError(f'{name}')
        scene_lens_in_acts = []
        for act in soup.find_all('div', {'type': 'act'}):
            scenes_list = act.find_all('div', {'type': 'scene'})
            scene_lens_in_acts.append(len(scenes_list))
        if all(elem > 0 for elem in scene_lens_in_acts):
            all_acts_have_scenes = True
            
        elif any(elem > 0 for elem in scene_lens_in_acts):
            all_acts_have_scenes = False
    else:
        all_acts_have_scenes = False
        
    ger_dracor_stats.append({'name': name, 
                             'prologue': prologue,
                             'acts': acts, 
                             'scenes': scenes, 
                             'all_acts_have_scenes': all_acts_have_scenes,
                             'configurations': configurations, 
                             'locations': locations})

# %%
with open('gerdracor_content_stats.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['name', 'prologue', 'acts', 'scenes', 'all_acts_have_scenes', 'configurations', 'locations'])
    writer.writeheader()
    for d in ger_dracor_stats:
        writer.writerow(d)
