# %%
import csv
from pathlib import Path
from itertools import combinations
from collections import defaultdict

import networkx as nx
from bs4 import BeautifulSoup

# %%
comedies_and_tragedies = {}
with open('fredracor-metadata.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if row['normalizedGenre'] in ['Tragedy', 'Comedy']:
            comedies_and_tragedies[row['name']] = row['normalizedGenre']

# %% [markdown]
# ### Files

# %%
fredracor_tei_files = '/home/misinagy/Projects/fredracor/tei'

# %% [markdown]
# ### FREDRACOR CUMULATIVE

# %% [markdown]
# ##### Helpers

# %%
def one_appearance_unit_edge_list(unit, lonely_nodes):
    """
    Take unit of BS4 tag and extract all connections between speakers in unit.
    """
    characters = []

    for sp in unit.find_all('sp', {'who': True}):
        # get each speaker from speaker tag
        speakers = sp['who'].split(' ')

        for split_sp in speakers:
            characters.append(split_sp)
    edge_list = list(combinations(set(characters), 2))
    # if only one character in scene, add lonely node
    if len(characters) == 1:
        lonely_nodes.append(characters[0])

    return edge_list, lonely_nodes


def get_largest_G(input_G, name=None):
    """
    Function to extract largest connected section of nx Graph object.
    """
    if len(input_G.nodes) == 0:
        raise ValueError(f'ZERO NODE GRAPH PASSED TO get_largest_G - {input_G}: {name}')
    if nx.is_connected(input_G) is False:
        # larges connected section
        nodes_in_largest = max(nx.connected_components(input_G), key=len)
        nodes_to_remove = set(input_G.nodes) - nodes_in_largest
        G_copy = input_G.copy()
        G_copy.remove_nodes_from(nodes_to_remove)
        return G_copy
    else:
        return input_G

# %% [markdown]
# ##### Collection

# %%
# SETTINGS
# Change these variables if needed!

# List of dramas to exclude (bad/different structure)
BLACKLIST = ['anonyme-vende']

# Tags to consider as acts
ACT_TAGS = ['act', 'acte', 'prologue', 'ate', 'partie', 'critique', 'tableau', 'intermede']

# Tags to consider as scenes
SCENE_TAGS = ['scene', 'ecene', 'zcene', 'scne', 'type', 'vaudeville', 'ballet', 'divertissement', 'epilogue', 'couplet', 'couplets', 'marche']

# %%
# open XML files of tragedy and comedy dramas, and parse soups where 'act' div is 5+ and there are
# 5+ characters.

def div_type_tag_count(s: BeautifulSoup, tag_names: list):
    total = 0
    for tag_name in tag_names:
        total += len(s.find_all('div', {'type': tag_name}))
    return total

fre_soups = {}
for xml_path in Path(fredracor_tei_files).glob('*.xml'):

    # Genres handled according to dracor metadata csv for consistency
    if xml_path.stem in comedies_and_tragedies and xml_path.stem not in BLACKLIST:
        with open(xml_path, 'r') as fh:
            # Filter 5 act, 5+ actor, Tragedy and Comedy dramas from GerDracor
            soup = BeautifulSoup(fh.read(), 'lxml-xml')

            acts_len = div_type_tag_count(soup, ACT_TAGS)

            cast_list = soup.find('profileDesc').find('listPerson').find_all('person')
            if cast_list is None:
                raise ValueError('No cast list found!')
            if acts_len == 5 and len(cast_list) > 5:
                fre_soups[xml_path.stem] = soup
print(f'{len(fre_soups)} collected')
# Out:
# 400 collected

# %%
# CREATE THE MAIN EXTRACTOR FUNCTION
# take first n acts from drama
def edge_list_extractor(list_of_soup_segments):
    """
    Takes list of soup elements, returns edge list for shared scenes, and if no scenes, just shared acts.
    This is GerDracor specific, and should only be used for the 128 dramas --> len(acts) == 5 and len(cast_list) > 5 and genre in ['Tragedy', 'Comedy']
    """

    lonely_nodes = []
    edge_list_in_iteration = []

    # iterate over n acts
    for c, act in enumerate(list_of_soup_segments, start=1):
        if act is None:
            if c == 1 or c == len(list_of_soup_segments):
                continue
            else:
                raise ValueError(f'ACT {c} IS NONE IN {name}')

        all_scene_type_tags = []
        for scene_type_tag in SCENE_TAGS:
            scene_type_tags = act.find_all('div', {'type': scene_type_tag})
            if len(scene_type_tags) > 0:
                all_scene_type_tags.extend(scene_type_tags)

        # IF IT HAS SCENES
        if len(all_scene_type_tags) > 0:
            for scene_tag in all_scene_type_tags:
                if scene_tag.find('div', {'type': 'scene'}) is not None:
                    print(f'Scene tag has scene tags')
                else:
                    scene_edge_list, lonely_nodes = one_appearance_unit_edge_list(scene_tag, lonely_nodes)
                    edge_list_in_iteration += scene_edge_list

        else:
            if any(act.find(elem) is not None for elem in ACT_TAGS):
                raise ValueError(f'Unaccounted div type in {name} !')
            act_edge_list, lonely_nodes = one_appearance_unit_edge_list(act, lonely_nodes)
            edge_list_in_iteration += act_edge_list

    return edge_list_in_iteration, lonely_nodes

# %%
# MAIN CUMULATIVE NETWORKS GENERATION FOR FREDRACOR

cumulative_G_list_fre = defaultdict(dict)

for name, soup in fre_soups.items():

    # Metadata annotation for dict
    cumulative_G_list_fre[name]['soup'] = soup
    cumulative_G_list_fre[name]['genre'] = comedies_and_tragedies[name]
    genre_tag = soup.find('textClass').find('keywords').find('term', {'type': 'genreTitle'})
    cumulative_G_list_fre[name]['title_pretty'] = soup.find('title').get_text(strip=True)

    # These are used to determine what structural elements there are.
    all_acts = []
    for act_tag_type in ACT_TAGS:
        all_acts.extend(soup.find_all('div', {'type': act_tag_type}))

    edge_list, lonely_nodes_main = edge_list_extractor(all_acts)
    # create network from edge list
    whole_drama = nx.from_edgelist(set(edge_list))

    # add those with independent scenes
    for lonely_node in lonely_nodes_main:
        if lonely_node not in whole_drama.nodes:
            whole_drama.add_node(lonely_node)

    cumulative_G_list_fre[name]['whole'] = whole_drama

    # Cumulative calculation
    print(f'Processing {name}', (50-(len(name)))*' ', end='')
    # create iterations for 1, 1-2, 1-2-3, ... acts

    current_iteration_rounds = []
    for iteration_round in range(1, len(all_acts)+1):  # was all_acts
        current_iteration_rounds.append(iteration_round)

        # take first n acts from drama
        acts_included = all_acts[:iteration_round]  # was all_acts
        print(f'-{len(acts_included)}', end='')

        edge_list_in_iteration_out, lonely_nodes_main = edge_list_extractor(acts_included)

        # create network from edge list
        n_acts_whole = nx.from_edgelist(set(edge_list_in_iteration_out))

        # add those with independent scenes
        for lonely_node in lonely_nodes_main:
            if lonely_node not in n_acts_whole.nodes:
                n_acts_whole.add_node(lonely_node)

        label = f"acts_{'-'.join([str(i) for i in current_iteration_rounds])}"

        cumulative_G_list_fre[name][label] = n_acts_whole
    print('\n---------------')
# Out:
# Processing magnon-sejanus                                     -1-2-3-4-5
# ---------------
# Processing tristan-mort-de-chrispe                            -1-2-3-4-5
# ---------------
# Processing genlis-amant-anonyme                               -1-2-3-4-5
# ---------------
# Processing crebillon-idomenee                                 -1-2-3-4-5
# ---------------
# Processing du-ryer-saul                                       -1-2-3-4-5
# ---------------
# Processing corneillep-pulcherie                               -1-2-3-4-5
# ---------------
# Processing la-calprenede-hermenegilde                         -1-2-3-4-5
# ---------------
# Processing soret-ceciliade                                    -1-2-3-4-5
# ---------------
# Processing quinault-bellerophon                               -1-2-3-4-5
# ---------------
# Processing scarron-fausse-apparence                           -1-2-3-4-5
# ---------------
# Processing voltaire-irene                                     -1-2-3-4-5
# ---------------
# Processing boyer-artaxerce                                    -1-2-3-4-5
# ---------------
# Processing crebillon-pyrrhus                                  -1-2-3-4-5
# ---------------
# Processing corneillep-clitandre                               -1-2-3-4-5
# ---------------
# Processing laignelot-agis                                     -1-2-3-4-5
# ---------------
# Processing auger-mort-de-caton                                -1-2-3-4-5
# ---------------
# Processing magnon-artaxerxe                                   -1-2-3-4-5
# ---------------
# Processing magnon-tamerlan                                    -1-2-3-4-5
# ---------------
# Processing marivaux-serments-indiscrets                       -1-2-3-4-5
# ---------------
# Processing racine-phedre-77                                   -1-2-3-4-5
# ---------------
# Processing dancourt-femme-d-intrigues                         -1-2-3-4-5
# ---------------
# Processing rotrou-hercule-mourant                             -1-2-3-4-5
# ---------------
# Processing rotrou-la-celimene                                 -1-2-3-4-5
# ---------------
# Processing genest-joseph                                      -1-2-3-4-5
# ---------------
# Processing viau-pasiphae                                      -1-2-3-4-5
# ---------------
# Processing voltaire-olympie                                   -1-2-3-4-5
# ---------------
# Processing pradon-statira                                     -1-2-3-4-5
# ---------------
# Processing corneillep-melite                                  -1-2-3-4-5
# ---------------
# Processing moliere-bourgeois-gentilhomme                      -1-2-3-4-5
# ---------------
# Processing palissot-ninus                                     -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-pandoste-ii                      -1-2-3-4-5
# ---------------
# Processing dufresny-regnard-chinois                           -1-2-3-4-5
# ---------------
# Processing aure-genevieve-70                                  -1-2-3-4-5
# ---------------
# Processing campistron-juba                                    -1-2-3-4-5
# ---------------
# Processing gresset-edouard-iii                                -1-2-3-4-5
# ---------------
# Processing voltaire-lois-de-minos                             -1-2-3-4-5
# ---------------
# Processing boursault-deux-freres-gemeaux                      -1-2-3-4-5
# ---------------
# Processing pacaroni-bajazet-premier                           -1-2-3-4-5
# ---------------
# Processing lagrange-chancel-amasis                            -1-2-3-4-5
# ---------------
# Processing racine-phedre                                      -1-2-3-4-5
# ---------------
# Processing desfontaines-perside                               -1-2-3-4-5
# ---------------
# Processing chevreau-la-lucrece-romaine                        -1-2-3-4-5
# ---------------
# Processing crebillon-atree-thyeste                            -1-2-3-4-5
# ---------------
# Processing corneillep-pertharite                              -1-2-3-4-5
# ---------------
# Processing guimont-de-la-touche-iphigenie                     -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-martyre-sainte-catherine         -1-2-3-4-5
# ---------------
# Processing scarron-gardien-de-soi-meme                        -1-2-3-4-5
# ---------------
# Processing moliere-misanthrope                                -1-2-3-4-5
# ---------------
# Processing corneillet-laodice                                 -1-2-3-4-5
# ---------------
# Processing jodelle-didon                                      -1-2-3-4-5
# ---------------
# Processing du-ryer-vendanges-de-suresnes                      -1-2-3-4-5
# ---------------
# Processing corneillep-don-sanche                              -1-2-3-4-5
# ---------------
# Processing scarron-jodelet                                    -1-2-3-4-5
# ---------------
# Processing benserade-mort-achille                             -1-2-3-4-5
# ---------------
# Processing moliere-festin-de-pierre                           -1-2-3-4-5
# ---------------
# Processing montchretien-lacenes                               -1-2-3-4-5
# ---------------
# Processing dufresny-jaloux-honteux                            -1-2-3-4-5
# ---------------
# Processing voltaire-scythes                                   -1-2-3-4-5
# ---------------
# Processing barbier-mort-de-cesar                              -1-2-3-4-5
# ---------------
# Processing corneillet-dom-bertran-de-cigarral                 -1-2-3-4-5
# ---------------
# Processing jaquelin-soliman                                   -1-2-3-4-5
# ---------------
# Processing voltaire-guebres                                   -1-2-3-4-5
# ---------------
# Processing fenelon-alexandre                                  -1-2-3-4-5
# ---------------
# Processing voltaire-enfant-prodigue                           -1-2-3-4-5
# ---------------
# Processing chabanon-eudoxie                                   -1-2-3-4-5
# ---------------
# Processing voltaire-oedipe-v                                  -1-2-3-4-5
# ---------------
# Processing regnard-distrait                                   -1-2-3-4-5
# ---------------
# Processing nadal-osarphis-moise                               -1-2-3-4-5
# ---------------
# Processing dufresny-reconciliation-normande                   -1-2-3-4-5
# ---------------
# Processing l-estoile-belle-esclave                            -1-2-3-4-5
# ---------------
# Processing voltaire-brutus                                    -1-2-3-4-5
# ---------------
# Processing corneillep-theodore                                -1-2-3-4-5
# ---------------
# Processing piron-ecole-peres                                  -1-2-3-4-5
# ---------------
# Processing racine-britannicus                                 -1-2-3-4-5
# ---------------
# Processing saint-aignan-martyre-marie-antoinette              -1-2-3-4-5
# ---------------
# Processing moliere-etourdi                                    -1-2-3-4-5
# ---------------
# Processing donneau-de-vise-dames-vengees                      -1-2-3-4-5
# ---------------
# Processing voltaire-tanis-zelide                              -1-2-3-4-5
# ---------------
# Processing racine-alexandre                                   -1-2-3-4-5
# ---------------
# Processing moliere-malade-imaginaire                          -1-2-3-4-5
# ---------------
# Processing boyera-caton                                       -1-2-3-4-5
# ---------------
# Processing voltaire-oreste                                    -1-2-3-4-5
# ---------------
# Processing rotrou-bague-de-l-oubli                            -1-2-3-4-5
# ---------------
# Processing moliere-tartuffe                                   -1-2-3-4-5
# ---------------
# Processing ouville-absent-chez-soi                            -1-2-3-4-5
# ---------------
# Processing crebillon-semiramis                                -1-2-3-4-5
# ---------------
# Processing de-caux-marius                                     -1-2-3-4-5
# ---------------
# Processing thibouville-thelamire                              -1-2-3-4-5
# ---------------
# Processing rotrou-l-heureuse-constance                        -1-2-3-4-5
# ---------------
# Processing corneillet-stlicon                                 -1-2-3-4-5
# ---------------
# Processing bohaire-jesus-christ                               -1-2-3-4-5
# ---------------
# Processing prade-arsace                                       -1-2-3-4-5
# ---------------
# Processing nivelle-gouvernante                                -1-2-3-4-5
# ---------------
# Processing quinault-mere-coquette                             -1-2-3-4-5
# ---------------
# Processing la-calprenede-phalante                             -1-2-3-4-5
# ---------------
# Processing la-motte-machabees                                 -1-2-3-4-5
# ---------------
# Processing corneillet-comtesse-orgueil                        -1-2-3-4-5
# ---------------
# Processing aubignac-pucelle                                   -1-2-3-4-5
# ---------------
# Processing corneillep-cinna                                   -1-2-3-4-5
# ---------------
# Processing delavigne-vepres-siciliennes                       -1-2-3-4-5
# ---------------
# Processing boyer-jeune-marius                                 -1-2-3-4-5
# ---------------
# Processing racine-andromaque                                  -1-2-3-4-5
# ---------------
# Processing rotrou-captifs                                     -1-2-3-4-5
# ---------------
# Processing corneillet-ariane                                  -1-2-3-4-5
# ---------------
# Processing corneillep-attila                                  -1-2-3-4-5
# ---------------
# Processing longepierre-la-mort-de-solon                       -1-2-3-4-5
# ---------------
# Processing barquebois-rapiniere                               -1-2-3-4-5
# ---------------
# Processing corneillet-mort-empereur-commode                   -1-2-3-4-5
# ---------------
# Processing nivelle-prejuge-a-la-mode                          -1-2-3-4-5
# ---------------
# Processing sommerive-bajazet                                  -1-2-3-4-5
# ---------------
# Processing fabre-d-eglantine-philinte-de-moliere              -1-2-3-4-5
# ---------------
# Processing lemierre-artaxerce                                 -1-2-3-4-5
# ---------------
# Processing tristan-osman                                      -1-2-3-4-5
# ---------------
# Processing boyer-agamemnon                                    -1-2-3-4-5
# ---------------
# Processing boursault-comedie-sans-titre                       -1-2-3-4-5
# ---------------
# Processing corneillet-camma                                   -1-2-3-4-5
# ---------------
# Processing voltaire-sophonisbe                                -1-2-3-4-5
# ---------------
# Processing racine-berenice                                    -1-2-3-4-5
# ---------------
# Processing champrepus-ulysse                                  -1-2-3-4-5
# ---------------
# Processing seneque-medee                                      -1-2-3-4-5
# ---------------
# Processing deshoulieres-genseric                              -1-2-3-4-5
# ---------------
# Processing rotrou-la-diane                                    -1-2-3-4-5
# ---------------
# Processing corneillep-cid                                     -1-2-3-4-5
# ---------------
# Processing diderot-pere-de-famille                            -1-2-3-4-5
# ---------------
# Processing voltaire-cafe                                      -1-2-3-4-5
# ---------------
# Processing marivaux-annibal                                   -1-2-3-4-5
# ---------------
# Processing crebillon-xerxes                                   -1-2-3-4-5
# ---------------
# Processing corneillet-dom-cesar-d-avalos                      -1-2-3-4-5
# ---------------
# Processing rotrou-le-filandre                                 -1-2-3-4-5
# ---------------
# Processing racine-athalie                                     -1-2-3-4-5
# ---------------
# Processing la-motte-carnaval-folie                            -1-2-3-4-5
# ---------------
# Processing corneillet-mort-annibal                            -1-2-3-4-5
# ---------------
# Processing genlis-mere-rivale                                 -1-2-3-4-5
# ---------------
# Processing colle-l-amant-anonyme                              -1-2-3-4-5
# ---------------
# Processing rostand-cyrano                                     -1-2-3-4-5
# ---------------
# Processing boissy-dehors-trompeurs                            -1-2-3-4-5
# ---------------
# Processing corneillet-timocrate                               -1-2-3-4-5
# ---------------
# Processing boursault-marie-stuard                             -1-2-3-4-5
# ---------------
# Processing brosse-turne                                       -1-2-3-4-5
# ---------------
# Processing quinault-comedie-sans-comedie                      -1-2-3-4-5
# ---------------
# Processing voltaire-zulime                                    -1-2-3-4-5
# ---------------
# Processing colardeau-astarbe                                  -1-2-3-4-5
# ---------------
# Processing corneillep-suite-menteur                           -1-2-3-4-5
# ---------------
# Processing grevin-cesar                                       -1-2-3-4-5
# ---------------
# Processing magnon-zenobie                                     -1-2-3-4-5
# ---------------
# Processing du-ryer-scevole                                    -1-2-3-4-5
# ---------------
# Processing corneillet-illustres-ennemis                       -1-2-3-4-5
# ---------------
# Processing chevreau-coriolan                                  -1-2-3-4-5
# ---------------
# Processing scarron-dom-japhet-d-armenie                       -1-2-3-4-5
# ---------------
# Processing henault-marius-a-cirte                             -1-2-3-4-5
# ---------------
# Processing gillet-deniaise                                    -1-2-3-4-5
# ---------------
# Processing cyrano-pedant-joue                                 -1-2-3-4-5
# ---------------
# Processing chenier-charles-ix                                 -1-2-3-4-5
# ---------------
# Processing dorat-celibataire                                  -1-2-3-4-5
# ---------------
# Processing rotrou-belle-alphrede                              -1-2-3-4-5
# ---------------
# Processing la-calprenede-mort-mitrhidate                      -1-2-3-4-5
# ---------------
# Processing boyer-aristodeme                                   -1-2-3-4-5
# ---------------
# Processing du-ryer-lucrece                                    -1-2-3-4-5
# ---------------
# Processing le-franc-didon                                     -1-2-3-4-5
# ---------------
# Processing aubignac-pucelle-prose                             -1-2-3-4-5
# ---------------
# Processing la-calprenede-jeanne                               -1-2-3-4-5
# ---------------
# Processing quinault-les-rivales                               -1-2-3-4-5
# ---------------
# Processing chabanon-faux-noble                                -1-2-3-4-5
# ---------------
# Processing regnard-legataire                                  -1-2-3-4-5
# ---------------
# Processing mareschala-veritable-capitaine-matamore            -1-2-3-4-5
# ---------------
# Processing dancourt-chevalier-a-la-mode                       -1-2-3-4-5
# ---------------
# Processing chevreau-avocat-dupe                               -1-2-3-4-5
# ---------------
# Processing lemierre-idomenee                                  -1-2-3-4-5
# ---------------
# Processing voltaire-tancrede                                  -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-le-pyrame                        -1-2-3-4-5
# ---------------
# Processing gilbert-semiramis                                  -1-2-3-4-5
# ---------------
# Processing ouville-fausses-verites                            -1-2-3-4-5
# ---------------
# Processing constant-wallstein                                 -1-2-3-4-5
# ---------------
# Processing boyer-clotilde                                     -1-2-3-4-5
# ---------------
# Processing piron-gustave-wasa                                 -1-2-3-4-5
# ---------------
# Processing linant-alzaide                                     -1-2-3-4-5
# ---------------
# Processing piron-metromanie                                   -1-2-3-4-5
# ---------------
# Processing pradon-mort-de-bajazet                             -1-2-3-4-5
# ---------------
# Processing corneillep-medee-39                                -1-2-3-4-5
# ---------------
# Processing nadal-herode                                       -1-2-3-4-5
# ---------------
# Processing monchretien-ecossaise-1604                         -1-2-3-4-5
# ---------------
# Processing boyer-porcie-romaine                               -1-2-3-4-5
# ---------------
# Processing gillet-francion                                    -1-2-3-4-5
# ---------------
# Processing lagrange-chancel-meleagre                          -1-2-3-4-5
# ---------------
# Processing hardy-meleagre                                     -1-2-3-4-5
# ---------------
# Processing abeille-argelie                                    -1-2-3-4-5
# ---------------
# Processing dancourt-bourgeoises-a-la-mode                     -1-2-3-4-5
# ---------------
# Processing cinq-auteurs-comedie-des-tuileries                 -1-2-3-4-5
# ---------------
# Processing moliere-avare                                      -1-2-3-4-5
# ---------------
# Processing corneillet-geolier-de-sois-meme                    -1-2-3-4-5
# ---------------
# Processing corneillep-rodogune                                -1-2-3-4-5
# ---------------
# Processing regnard-sapor                                      -1-2-3-4-5
# ---------------
# Processing nadal-antiochus                                    -1-2-3-4-5
# ---------------
# Processing corneillep-menteur                                 -1-2-3-4-5
# ---------------
# Processing voltaire-alzire                                    -1-2-3-4-5
# ---------------
# Processing donneau-de-vise-corneille-devineresse              -1-2-3-4-5
# ---------------
# Processing tristan-mort-seneque                               -1-2-3-4-5
# ---------------
# Processing abeille-lyncee                                     -1-2-3-4-5
# ---------------
# Processing campistron-arminiusc                               -1-2-3-4-5
# ---------------
# Processing magnon-jeanne-de-naples                            -1-2-3-4-5
# ---------------
# Processing l-estoile-intrigue-des-filous                      -1-2-3-4-5
# ---------------
# Processing cailhava-egoisme                                   -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-thesee                           -1-2-3-4-5
# ---------------
# Processing voltaire-merope                                    -1-2-3-4-5
# ---------------
# Processing corneillep-tite                                    -1-2-3-4-5
# ---------------
# Processing cyrano-la-mort-d-agrippine                         -1-2-3-4-5
# ---------------
# Processing desfontaines-saint-genest                          -1-2-3-4-5
# ---------------
# Processing la-calprenede-enfants-d-herode                     -1-2-3-4-5
# ---------------
# Processing corneillet-persee-demetrius                        -1-2-3-4-5
# ---------------
# Processing boyer-judith                                       -1-2-3-4-5
# ---------------
# Processing sand-moliere                                       -1-2-3-4-5
# ---------------
# Processing haren-agon                                         -1-2-3-4-5
# ---------------
# Processing delavigne-comediens                                -1-2-3-4-5
# ---------------
# Processing montchretien-carthaginoise                         -1-2-3-4-5
# ---------------
# Processing legouve-laurence-orzano                            -1-2-3-4-5
# ---------------
# Processing la-harpe-comte-de-warwick                          -1-2-3-4-5
# ---------------
# Processing moliere-dom-garcie-de-navarre                      -1-2-3-4-5
# ---------------
# Processing lemierre-guillaume-tell                            -1-2-3-4-5
# ---------------
# Processing corneillep-mort-pompee                             -1-2-3-4-5
# ---------------
# Processing corneillet-charme-de-la-voix                       -1-2-3-4-5
# ---------------
# Processing boyer-mort-enfants-brute                           -1-2-3-4-5
# ---------------
# Processing duche-absalon                                      -1-2-3-4-5
# ---------------
# Processing scarron-heritier-ridicule                          -1-2-3-4-5
# ---------------
# Processing bernard-laodamie                                   -1-2-3-4-5
# ---------------
# Processing mairet-sophonisbe                                  -1-2-3-4-5
# ---------------
# Processing chevalier-pedagogue-amoureux                       -1-2-3-4-5
# ---------------
# Processing racine-bajazet                                     -1-2-3-4-5
# ---------------
# Processing dufresny-joueuse                                   -1-2-3-4-5
# ---------------
# Processing montchretien-david                                 -1-2-3-4-5
# ---------------
# Processing montchretien-hector                                -1-2-3-4-5
# ---------------
# Processing le-vayer-grand-selim                               -1-2-3-4-5
# ---------------
# Processing brosse-aveugle-clairvoyant                         -1-2-3-4-5
# ---------------
# Processing boyer-oropaste                                     -1-2-3-4-5
# ---------------
# Processing rotrou-cosroes                                     -1-2-3-4-5
# ---------------
# Processing corneillep-othon                                   -1-2-3-4-5
# ---------------
# Processing regnard-democrite                                  -1-2-3-4-5
# ---------------
# Processing la-fontaine-eunuque                                -1-2-3-4-5
# ---------------
# Processing seneque-agamemnon                                  -1-2-3-4-5
# ---------------
# Processing scudery-arminius                                   -1-2-3-4-5
# ---------------
# Processing rotrou-crisante                                    -1-2-3-4-5
# ---------------
# Processing bievre-seducteur                                   -1-2-3-4-5
# ---------------
# Processing corneillet-darius                                  -1-2-3-4-5
# ---------------
# Processing dufresny-malade-sans-maladie                       -1-2-3-4-5
# ---------------
# Processing genest-zelonide                                    -1-2-3-4-5
# ---------------
# Processing dufresny-faux-sincere                              -1-2-3-4-5
# ---------------
# Processing dancourt-madame-artus                              -1-2-3-4-5
# ---------------
# Processing scarron-prince-corsaire                            -1-2-3-4-5
# ---------------
# Processing aure-dipne                                         -1-2-3-4-5
# ---------------
# Processing corneillep-cinna-43                                -1-2-3-4-5
# ---------------
# Processing du-ryer-alcionee                                   -1-2-3-4-5
# ---------------
# Processing racine-iphigenie                                   -1-2-3-4-5
# ---------------
# Processing arnault-lucrece                                    -1-2-3-4-5
# ---------------
# Processing corneillep-place-royale                            -1-2-3-4-5
# ---------------
# Processing gillet-campagnard                                  -1-2-3-4-5
# ---------------
# Processing boissy-medecin-par-occasion                        -1-2-3-4-5
# ---------------
# Processing corneillep-medee                                   -1-2-3-4-5
# ---------------
# Processing blanc-druides                                      -1-2-3-4-5
# ---------------
# Processing discret-noces-de-vaugirard                         -1-2-3-4-5
# ---------------
# Processing voltaire-adelaide                                  -1-2-3-4-5
# ---------------
# Processing racine-andromaque-68                               -1-2-3-4-5
# ---------------
# Processing rotrou-saint-genest                                -1-2-3-4-5
# ---------------
# Processing boissy-homme-du-jour                               -1-2-3-4-5
# ---------------
# Processing voltaire-mariamne                                  -1-2-3-4-5
# ---------------
# Processing voltaire-fanatisme                                 -1-2-3-4-5
# ---------------
# Processing lagrange-chancel-oreste                            -1-2-3-4-5
# ---------------
# Processing bernard-brutus                                     -1-2-3-4-5
# ---------------
# Processing la-fosse-manlius                                   -1-2-3-4-5
# ---------------
# Processing dancourt-trahison-punie                            -1-2-3-4-5
# ---------------
# Processing corneillet-berenice                                -1-2-3-4-5
# ---------------
# Processing vallee-fidele-esclave                              -1-2-3-4-5
# ---------------
# Processing voltaire-orphelin-de-la-chine                      -1-2-3-4-5
# ---------------
# Processing nivelle-ecole-des-amis                             -1-2-3-4-5
# ---------------
# Processing aure-genevieve-69                                  -1-2-3-4-5
# ---------------
# Processing saurin-amenophis                                   -1-2-3-4-5
# ---------------
# Processing corneillep-sertorius                               -1-2-3-4-5
# ---------------
# Processing boissy-comte-de-neuilly                            -1-2-3-4-5
# ---------------
# Processing poinsinet-ajax                                     -1-2-3-4-5
# ---------------
# Processing hauteroche-amant-flatte-point                      -1-2-3-4-5
# ---------------
# Processing rotrou-antigone                                    -1-2-3-4-5
# ---------------
# Processing la-mesnardiere-alinde                              -1-2-3-4-5
# ---------------
# Processing corneillep-melite-33                               -1-2-3-4-5
# ---------------
# Processing pellegrin-tibere                                   -1-2-3-4-5
# ---------------
# Processing voltaire-agathocle                                 -1-2-3-4-5
# ---------------
# Processing regnard-joueur                                     -1-2-3-4-5
# ---------------
# Processing la-motte-ines-de-castro                            -1-2-3-4-5
# ---------------
# Processing benserade-cleopatre                                -1-2-3-4-5
# ---------------
# Processing la-calprenede-comte-d-essex                        -1-2-3-4-5
# ---------------
# Processing corneillep-heraclius                               -1-2-3-4-5
# ---------------
# Processing corneillet-comte-d-essex                           -1-2-3-4-5
# ---------------
# Processing abeille-coriolan                                   -1-2-3-4-5
# ---------------
# Processing montgaudier-natalie                                -1-2-3-4-5
# ---------------
# Processing scudery-fils-suppose                               -1-2-3-4-5
# ---------------
# Processing racine-mithridate                                  -1-2-3-4-5
# ---------------
# Processing pradon-phedre                                      -1-2-3-4-5
# ---------------
# Processing sedaine-le-philosophe-sans-le-savoir               -1-2-3-4-5
# ---------------
# Processing boyer-tiridate                                     -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-sac-de-carthage                  -1-2-3-4-5
# ---------------
# Processing ouville-soupcons                                   -1-2-3-4-5
# ---------------
# Processing corneillet-theodat                                 -1-2-3-4-5
# ---------------
# Processing saurin-blanche-et-guiscard                         -1-2-3-4-5
# ---------------
# Processing crebillon-catilina                                 -1-2-3-4-5
# ---------------
# Processing vallee-forte-romaine                               -1-2-3-4-5
# ---------------
# Processing crebillon-triumvirat                               -1-2-3-4-5
# ---------------
# Processing du-ryer-esther                                     -1-2-3-4-5
# ---------------
# Processing quinault-astrate                                   -1-2-3-4-5
# ---------------
# Processing campistron-alcibiade                               -1-2-3-4-5
# ---------------
# Processing corneillep-veuve-34                                -1-2-3-4-5
# ---------------
# Processing dancourt-enfants-de-paris                          -1-2-3-4-5
# ---------------
# Processing la-fontaine-ragotin                                -1-2-3-4-5
# ---------------
# Processing lemierre-veuve-malabar                             -1-2-3-4-5
# ---------------
# Processing voltaire-zaire                                     -1-2-3-4-5
# ---------------
# Processing legouve-attilie                                    -1-2-3-4-5
# ---------------
# Processing turnebe-contents                                   -1-2-3-4-5
# ---------------
# Processing scarron-jodelet-dueliste                           -1-2-3-4-5
# ---------------
# Processing racine-thebaide-64                                 -1-2-3-4-5
# ---------------
# Processing racine-thebaide                                    -1-2-3-4-5
# ---------------
# Processing nadal-mariamne                                     -1-2-3-4-5
# ---------------
# Processing voltaire-rome-sauvee                               -1-2-3-4-5
# ---------------
# Processing corneillep-horace                                  -1-2-3-4-5
# ---------------
# Processing rotrou-belisaire                                   -1-2-3-4-5
# ---------------
# Processing voltaire-pelopides                                 -1-2-3-4-5
# ---------------
# Processing corneillet-mort-d-achille                          -1-2-3-4-5
# ---------------
# Processing mareschala-jugement                                -1-2-3-4-5
# ---------------
# Processing genest-penelope                                    -1-2-3-4-5
# ---------------
# Processing corneillet-festin-pierre                           -1-2-3-4-5
# ---------------
# Processing voltaire-depositaire                               -1-2-3-4-5
# ---------------
# Processing campistron-virginie                                -1-2-3-4-5
# ---------------
# Processing mareschala-railleur                                -1-2-3-4-5
# ---------------
# Processing palaprat-le-muet                                   -1-2-3-4-5
# ---------------
# Processing nericault-glorieux                                 -1-2-3-4-5
# ---------------
# Processing baro-saint-eustache                                -1-2-3-4-5
# ---------------
# Processing dancourt-sancho                                    -1-2-3-4-5
# ---------------
# Processing pure-ostorius                                      -1-2-3-4-5
# ---------------
# Processing crebillon-rhadamisthe                              -1-2-3-4-5
# ---------------
# Processing corneillet-feint-astrologue                        -1-2-3-4-5
# ---------------
# Processing pradon-regulus                                     -1-2-3-4-5
# ---------------
# Processing la-thuilerie-hercule                               -1-2-3-4-5
# ---------------
# Processing corneillep-surena                                  -1-2-3-4-5
# ---------------
# Processing scarron-marquis-ridicule                           -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-thomas-morus                     -1-2-3-4-5
# ---------------
# Processing corneillep-agesilas                                -1-2-3-4-5
# ---------------
# Processing corneillep-oedipe                                  -1-2-3-4-5
# ---------------
# Processing cinq-auteurs-aveugle-de-smyrne                     -1-2-3-4-5
# ---------------
# Processing corneillep-nicomede                                -1-2-3-4-5
# ---------------
# Processing cheron-homme-a-bonnes-fortunes                     -1-2-3-4-5
# ---------------
# Processing corneillet-baron-d-albikrac                        -1-2-3-4-5
# ---------------
# Processing nadal-saul                                         -1-2-3-4-5
# ---------------
# Processing campistron-tiridate                                -1-2-3-4-5
# ---------------
# Processing corneillep-veuve                                   -1-2-3-4-5
# ---------------
# Processing la-chapelle-zaide                                  -1-2-3-4-5
# ---------------
# Processing du-ryer-themistocle                                -1-2-3-4-5
# ---------------
# Processing nivelle-ecole-meres                                -1-2-3-4-5
# ---------------
# Processing corneillet-amour-a-la-mode                         -1-2-3-4-5
# ---------------
# Processing pechantre-geta                                     -1-2-3-4-5
# ---------------
# Processing leclerc-iphigenie                                  -1-2-3-4-5
# ---------------
# Processing campistron-andronic                                -1-2-3-4-5
# ---------------
# Processing corneillep-illusion-comique                        -1-2-3-4-5
# ---------------
# Processing campistron-phocion                                 -1-2-3-4-5
# ---------------
# Processing legouve-polixene                                   -1-2-3-4-5
# ---------------
# Processing voltaire-semiramis                                 -1-2-3-4-5
# ---------------
# Processing pousset-de-montauban-zenobie                       -1-2-3-4-5
# ---------------
# Processing corneillep-sophonisbe                              -1-2-3-4-5
# ---------------
# Processing ronsin-aretaphile                                  -1-2-3-4-5
# ---------------
# Processing voltaire-droit-du-seigneur                         -1-2-3-4-5
# ---------------
# Processing boyer-porus                                        -1-2-3-4-5
# ---------------
# Processing campistron-pompeia                                 -1-2-3-4-5
# ---------------
# Processing desfontaines-veritable-semiramis                   -1-2-3-4-5
# ---------------
# Processing montchretien-aman                                  -1-2-3-4-5
# ---------------
# Processing dalibray-le-torrismon-du-tasse                     -1-2-3-4-5
# ---------------
# Processing pradon-scipion                                     -1-2-3-4-5
# ---------------
# Processing boursault-germanicus                               -1-2-3-4-5
# ---------------
# Processing viau-pyrame                                        -1-2-3-4-5
# ---------------
# Processing corneillet-engagements-du-hasard                   -1-2-3-4-5
# ---------------
# Processing corneillet-galant-double                           -1-2-3-4-5
# ---------------
# Processing bohaire-siege-de-paris                             -1-2-3-4-5
# ---------------
# Processing moliere-femmes-savantes                            -1-2-3-4-5
# ---------------
# Processing puget-de-la-serre-pandoste-i                       -1-2-3-4-5
# ---------------
# Processing tanevot-adam-et-eve                                -1-2-3-4-5
# ---------------
# Processing moliere-ecole-des-femmes                           -1-2-3-4-5
# ---------------
# Processing chamfort-mustapha-zeangir                          -1-2-3-4-5
# ---------------
# Processing moliere-depit-amoureux                             -1-2-3-4-5
# ---------------
# Processing corneillep-suivante                                -1-2-3-4-5
# ---------------
# Processing corneillep-polyeucte                               -1-2-3-4-5
# ---------------
# Processing corneillep-galerie-du-palais                       -1-2-3-4-5
# ---------------
# Processing racine-alexandre-66                                -1-2-3-4-5
# ---------------
# Processing gudin-lothaire                                     -1-2-3-4-5
# ---------------
# Processing corneillet-maximian                                -1-2-3-4-5
# ---------------
# Processing legouve-eteocle                                    -1-2-3-4-5
# ---------------
# Processing graffigny-cenie                                    -1-2-3-4-5
# ---------------
# Processing corneillet-pyrrhus                                 -1-2-3-4-5
# ---------------
# Processing folard-themistocle                                 -1-2-3-4-5
# ---------------
# Processing tristan-parasite                                   -1-2-3-4-5
# ---------------
# Processing longepierre-medee                                  -1-2-3-4-5
# ---------------
# Processing regnard-menechmes                                  -1-2-3-4-5
# ---------------
# Processing corneillet-bradamante                              -1-2-3-4-5
# ---------------
# Processing moliere-dom-juan                                   -1-2-3-4-5
# ---------------
# Processing crebillon-electre                                  -1-2-3-4-5
# ---------------
# Processing campistron-adrien                                  -1-2-3-4-5
# ---------------
# Processing carrion-nizas-pierre-le-grand                      -1-2-3-4-5
# ---------------
# Processing desmarets-visionnaires                             -1-2-3-4-5
# ---------------

# %% [markdown]
# ##### CSV WRITING FOR FREDRACOR RESULTS

# %%
# Write csvs

csv_filename = 'fredracor_cumulative.csv'
column_names = ['title', 'title_pretty', 'genre']
metric_names = ['density', 'diameter', 'average_clustering']
most_acts = max([len(v) for v in cumulative_G_list_fre.values()]) - 1

for act in range(1, 5+1):
    for n in metric_names:
        column_names.append(f"acts_{'-'.join([str(n) for n in range(1, act+1)])}_{n}")

ger_result_dict = defaultdict(dict)
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=column_names)
    writer.writeheader()

    for name, drama_data in cumulative_G_list_fre.items():
        drama_dict = {'title': name,
                      'title_pretty': drama_data['title_pretty'],
                      'genre': drama_data['genre']}

        for act in range(1, 5+1):
            acts_name = f"acts_{'-'.join([str(n) for n in range(1, act+1)])}"
            if acts_name in drama_data.keys():
                drama_dict[f"{acts_name}_density"] = nx.density(drama_data[acts_name])
                drama_dict[f'{acts_name}_diameter'] = nx.diameter(get_largest_G(drama_data[acts_name], name))
                drama_dict[f'{acts_name}_average_clustering'] = nx.average_clustering(drama_data[acts_name])
            else:
                raise ValueError(f'{acts_name} not in {name}')
        ger_result_dict[name] = drama_dict
        writer.writerow(drama_dict)
